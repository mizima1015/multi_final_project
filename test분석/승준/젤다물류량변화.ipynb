# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import chardet

# %%
# 데이터를 바이트 형태로 바꿔 인코딩을 모르더라도 읽을 수 있게 변환

# %%
import chardet    

with open("ss05.csv", 'rb') as file: 
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
ss05 = pd.read_csv("ss05.csv", encoding = 'EUC-KR')
st05 = pd.read_csv("st05.csv", encoding = 'EUC-KR')
ts05 = pd.read_csv("ts05.csv", encoding = 'EUC-KR')

# %%
ss05.head()
# Out:
#           날짜    발송시  발송구    수령시  수령구  가구/인테리어    기타  도서/음반  디지털/가전  생활/건강  \
# 0 2023-05-04  서울특별시  구로구  서울특별시  종로구      3.0  21.0    7.0     9.0   21.0
# 1 2023-05-04  서울특별시  구로구  서울특별시   중구      8.0  20.0    4.0    29.0   23.0
# 2 2023-05-04  서울특별시  구로구  서울특별시  용산구      7.0  41.0   10.0    21.0   17.0
# 3 2023-05-04  서울특별시  구로구  서울특별시  성동구      5.0  52.0   19.0    20.0   23.0
# 4 2023-05-04  서울특별시  구로구  서울특별시  광진구      8.0  61.0    7.0    25.0   26.0
#
#    스포츠/레저    식품  출산/육아  패션의류  패션잡화  화장품/미용
# 0     0.0   3.0    0.0  36.0   9.0     4.0
# 1    10.0   0.0    0.0  34.0  12.0     7.0
# 2     9.0  11.0    3.0  34.0   4.0    11.0
# 3     5.0   0.0    0.0  85.0  13.0    10.0
# 4     6.0   4.0    4.0  51.0  12.0    21.0

# %%
ss05.drop(["SEND_CTPV_CD", "SEND_CTGG_CD", "REC_CTGG_CD", "REC_CTPV_CD"], axis=1, inplace=True) # 지역코드 칼럼 종류 모두 적어서 제거

# %%
ss05.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "SEND_CTGG_NM" : "발송구",
    "REC_CTPV_NM" : "수령시",
    "REC_CTGG_NM" : "수령구"    
}, inplace = True)

# %%
ss05.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)

# %%
st05.head()
# Out:
#           날짜    발송시  발송구    수령시  가구/인테리어     기타  도서/음반  디지털/가전   생활/건강  \
# 0 2023-05-22  서울특별시  양천구  서울특별시     75.0  671.0  289.0   708.0  1230.0
# 1 2023-05-22  서울특별시  양천구  부산광역시     30.0  126.0   51.0   162.0   333.0
# 2 2023-05-22  서울특별시  양천구  대구광역시     24.0   99.0   34.0   120.0   240.0
# 3 2023-05-22  서울특별시  양천구  인천광역시     30.0  170.0   52.0   161.0   394.0
# 4 2023-05-22  서울특별시  양천구  광주광역시     12.0   71.0   22.0    66.0   159.0
#
#    스포츠/레저     식품  출산/육아    패션의류   패션잡화  화장품/미용
# 0   270.0  661.0   61.0  1972.0  850.0   532.0
# 1    51.0  172.0    8.0   436.0  208.0   150.0
# 2    39.0  113.0   13.0   323.0  127.0    87.0
# 3    73.0  192.0   12.0   497.0  203.0   132.0
# 4    14.0   74.0   12.0   207.0   92.0    70.0

# %%
st05.drop(["REC_CTPV_CD"], axis=1, inplace=True)

# %%
st05.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "SEND_CTGG_NM" : "발송구",
    "REC_CTPV_NM" : "수령시",   
}, inplace = True)

# %%
st05.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)

# %%
ts05.head()
# Out:
#           날짜   발송시    수령시  수령구  가구/인테리어    기타  도서/음반  디지털/가전  생활/건강  스포츠/레저  \
# 0 2023-05-03  경상남도  서울특별시  종로구      7.0  13.0    0.0    14.0   39.0     0.0
# 1 2023-05-03  경상남도  서울특별시   중구      3.0  29.0    0.0     5.0   42.0     6.0
# 2 2023-05-03  경상남도  서울특별시  용산구      3.0  15.0    0.0    28.0   56.0    11.0
# 3 2023-05-03  경상남도  서울특별시  성동구      8.0  82.0    0.0    13.0   46.0    13.0
# 4 2023-05-03  경상남도  서울특별시  광진구      9.0  27.0    0.0    21.0   65.0    13.0
#
#       식품  출산/육아  패션의류  패션잡화  화장품/미용
# 0  100.0   11.0  20.0   6.0     0.0
# 1  102.0   15.0  48.0   9.0     0.0
# 2  120.0   12.0  28.0   9.0     0.0
# 3  146.0   18.0  63.0  17.0     0.0
# 4  114.0   12.0  26.0   7.0     6.0

# %%
ts05.drop(["SEND_CTPV_CD", "REC_CTPV_CD","REC_CTGG_CD"], axis=1, inplace=True)

# %%
ts05.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "REC_CTPV_NM" : "수령시",
    "REC_CTGG_NM" : "수령구"    
}, inplace = True)

# %%
ts05.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)

# %%
print(ss05['날짜'].dtype)
# Out:
# datetime64[ns]

# %%
print(st05['날짜'].dtype)
print(ts05['날짜'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
ss05['날짜'] = pd.to_datetime(ss05['날짜'], format='%Y%m%d') # 날짜를 pandas datetime64 타입으로 변경

# %%
st05['날짜'] = pd.to_datetime(st05['날짜'], format='%Y%m%d')
ts05['날짜'] = pd.to_datetime(ts05['날짜'], format='%Y%m%d')

# %%
ss04 = pd.read_csv("ss04.csv", encoding = 'EUC-KR')
st04 = pd.read_csv("st04.csv", encoding = 'EUC-KR')
ts04 = pd.read_csv("ts04.csv", encoding = 'EUC-KR')

# %%
ss04.drop(["SEND_CTPV_CD", "SEND_CTGG_CD", "REC_CTGG_CD", "REC_CTPV_CD"], axis=1, inplace=True)
st04.drop(["SEND_CTPV_CD", "SEND_CTGG_CD", "REC_CTPV_CD"], axis=1, inplace=True)
ts04.drop(["SEND_CTPV_CD", "REC_CTPV_CD","REC_CTGG_CD"], axis=1, inplace=True)

# %%
ss04.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "SEND_CTGG_NM" : "발송구",
    "REC_CTPV_NM" : "수령시",
    "REC_CTGG_NM" : "수령구"    
}, inplace = True)

st04.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "SEND_CTGG_NM" : "발송구",
    "REC_CTPV_NM" : "수령시",   
}, inplace = True)

ts04.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "REC_CTPV_NM" : "수령시",
    "REC_CTGG_NM" : "수령구"    
}, inplace = True)

# %%
ss04.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)
st04.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)
ts04.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)

# %%
ss04['날짜'] = pd.to_datetime(ss04['날짜'], format='%Y%m%d')
st04['날짜'] = pd.to_datetime(st04['날짜'], format='%Y%m%d')
ts04['날짜'] = pd.to_datetime(ts04['날짜'], format='%Y%m%d')

# %%
print(ss04['날짜'].dtype)
print(st04['날짜'].dtype)
print(ts04['날짜'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 설치된 폰트를 출력합니다.
# 'Hangul'이 포함된 폰트 이름을 찾습니다
for font in fm.fontManager.ttflist:
    if 'Hangul' in font.name:  .
        print(font.name)

# %%
import matplotlib.font_manager as fm

# 존재하는 폰트 확인
fonts = set([f.name for f in fm.fontManager.ttflist])
for f in sorted(fonts):
    print(f)
# Out:
# Agency FB
# Algerian
# Ami R
# Arial
# Arial Rounded MT Bold
# Bahnschrift
# Baskerville Old Face
# Batang
# Bauhaus 93
# Bell MT
# Berlin Sans FB
# Berlin Sans FB Demi
# Bernard MT Condensed
# Blackadder ITC
# Bodoni MT
# Book Antiqua
# Bookman Old Style
# Bookshelf Symbol 7
# Bradley Hand ITC
# Britannic Bold
# Broadway
# Brush Script MT
# Calibri
# Californian FB
# Calisto MT
# Cambria
# Candara
# Castellar
# Centaur
# Century
# Century Gothic
# Century Schoolbook
# Chiller
# Colonna MT
# Comic Sans MS
# Consolas
# Constantia
# Cooper Black
# Copperplate Gothic Bold
# Copperplate Gothic Light
# Corbel
# Courier New
# Curlz MT
# DejaVu Sans
# DejaVu Sans Display
# DejaVu Sans Mono
# DejaVu Serif
# DejaVu Serif Display
# Dubai
# Ebrima
# Edwardian Script ITC
# Elephant
# Engravers MT
# Eras Bold ITC
# Eras Demi ITC
# Eras Light ITC
# Eras Medium ITC
# Felix Titling
# Footlight MT Light
# Forte
# Franklin Gothic Book
# Franklin Gothic Demi
# Franklin Gothic Demi Cond
# Franklin Gothic Heavy
# Franklin Gothic Medium
# Franklin Gothic Medium Cond
# Freestyle Script
# French Script MT
# Gabriola
# Gadugi
# Garamond
# Georgia
# Gigi
# Gill Sans MT
# Gill Sans MT Condensed
# Gill Sans MT Ext Condensed Bold
# Gill Sans Ultra Bold
# Gill Sans Ultra Bold Condensed
# Gloucester MT Extra Condensed
# Goudy Old Style
# Goudy Stout
# Gulim
# HYGothic-Extra
# HYGothic-Medium
# HYGraphic-Medium
# HYGungSo-Bold
# HYHeadLine-Medium
# HYMyeongJo-Extra
# HYPMokGak-Bold
# HYPost-Light
# HYPost-Medium
# HYShortSamul-Medium
# HYSinMyeongJo-Medium
# Haettenschweiler
# Harlow Solid Italic
# Harrington
# Headline R
# High Tower Text
# HoloLens MDL2 Assets
# Impact
# Imprint MT Shadow
# Informal Roman
# Ink Free
# Javanese Text
# Jokerman
# Juice ITC
# Kristen ITC
# Kunstler Script
# Leelawadee UI
# Lucida Bright
# Lucida Calligraphy
# Lucida Console
# Lucida Fax
# Lucida Handwriting
# Lucida Sans
# Lucida Sans Typewriter
# Lucida Sans Unicode
# MS Gothic
# MS Outlook
# MS Reference Sans Serif
# MS Reference Specialty
# MT Extra
# MV Boli
# Magic R
# Magneto
# Maiandra GD
# Malgun Gothic
# Matura MT Script Capitals
# Microsoft Himalaya
# Microsoft JhengHei
# Microsoft New Tai Lue
# Microsoft PhagsPa
# Microsoft Sans Serif
# Microsoft Tai Le
# Microsoft YaHei
# Microsoft Yi Baiti
# MingLiU-ExtB
# Mistral
# Modern No. 20
# MoeumT R
# Mongolian Baiti
# Monotype Corsiva
# Myanmar Text
# New Gulim
# Niagara Engraved
# Niagara Solid
# Nirmala UI
# OCR A Extended
# Old English Text MT
# Onyx
# Palace Script MT
# Palatino Linotype
# Papyrus
# Parchment
# Perpetua
# Perpetua Titling MT
# Playbill
# Poor Richard
# Pristina
# Pyunji R
# Rage Italic
# Ravie
# Rockwell
# Rockwell Condensed
# Rockwell Extra Bold
# STIXGeneral
# STIXNonUnicode
# STIXSizeFiveSym
# STIXSizeFourSym
# STIXSizeOneSym
# STIXSizeThreeSym
# STIXSizeTwoSym
# Sans Serif Collection
# Script MT Bold
# Segoe Fluent Icons
# Segoe MDL2 Assets
# Segoe Print
# Segoe Script
# Segoe UI
# Segoe UI Emoji
# Segoe UI Historic
# Segoe UI Symbol
# Segoe UI Variable
# Showcard Gothic
# SimSun
# SimSun-ExtB
# Sitka
# Snap ITC
# Stencil
# Sylfaen
# Symbol
# Tahoma
# Tempus Sans ITC
# Times New Roman
# Trebuchet MS
# Tw Cen MT
# Tw Cen MT Condensed
# Tw Cen MT Condensed Extra Bold
# Verdana
# Viner Hand ITC
# Vivaldi
# Vladimir Script
# Webdings
# Wide Latin
# Wingdings
# Wingdings 2
# Wingdings 3
# Yet R
# Yu Gothic
# cmb10
# cmex10
# cmmi10
# cmr10
# cmss10
# cmsy10
# cmtt10

# %%
# 맑음 고딕채로 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
ss05 = ss05.sort_values(by='날짜')
st05 = st05.sort_values(by='날짜')
ts05 = ts05.sort_values(by='날짜')

# %%
ss04 = ss04.sort_values(by='날짜')
st04 = st04.sort_values(by='날짜')
ts04 = ts04.sort_values(by='날짜')

# %%
ss05_D = ss05[['날짜', '디지털/가전']]

# %%
ss04_D = ss04[['날짜', '디지털/가전']]

# %%
ss05_D = ss05_D.groupby('날짜')['디지털/가전'].sum().reset_index()

# %%
ss04_D = ss04_D.groupby('날짜')['디지털/가전'].sum().reset_index()

# %%
ss05_D.head()
# Out:
#           날짜   디지털/가전
# 0 2023-05-01  10529.0
# 1 2023-05-02  29348.0
# 2 2023-05-03   6006.0
# 3 2023-05-04  17406.0
# 4 2023-05-05     28.0

# %%
ss04_D.head()
# Out:
#           날짜   디지털/가전
# 0 2023-04-01    954.0
# 1 2023-04-02     20.0
# 2 2023-04-03  31438.0
# 3 2023-04-04  20509.0
# 4 2023-04-05  19422.0

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.bar(ss05_D['날짜'], ss05_D['디지털/가전'])
ax.set_title('디지털/가전 판매 추이')
ax.set_xlabel('날짜')
ax.set_ylabel('판매량')

date_labels = ss05_D['날짜'].dt.strftime('%Y-%m-%d') # day까지만 출력하도록 설정
ax.set_xticks(ss05_D['날짜'])
ax.set_xticklabels(date_labels, rotation=90)

plt.tight_layout() # 잘 보이게끔 레이아웃 자동 조정

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))  # 그래프 크기 조정

# 4월 데이터를 위한 막대
ax.bar(ss04_D['날짜'], ss04_D['디지털/가전'], color='blue', label='4월')

# 5월 데이터를 위한 막대
ax.bar(ss05_D['날짜'], ss05_D['디지털/가전'], color='green', label='5월')

ax.set_title('디지털/가전 판매 추이')
ax.set_xlabel('날짜')
ax.set_ylabel('판매량')

# 날짜 레이블 조정
date_labels = ss04_D['날짜'].dt.strftime('%Y-%m-%d').tolist() + ss05_D['날짜'].dt.strftime('%Y-%m-%d').tolist()
ax.set_xticks(date_labels)  # 4월과 5월 날짜를 모두 포함하도록 설정
ax.set_xticklabels(date_labels, rotation=90)

# 범례 추가
ax.legend()

plt.tight_layout()
plt.show()

# %%
# 데이터프레임을 합치기
ss_04_05_D = pd.concat([ss04_D, ss05_D], ignore_index=True)
ss_04_05_D
# Out:
#            날짜   디지털/가전
# 0  2023-04-01    954.0
# 1  2023-04-02     20.0
# 2  2023-04-03  31438.0
# 3  2023-04-04  20509.0
# 4  2023-04-05  19422.0
# ..        ...      ...
# 56 2023-05-27      6.0
# 57 2023-05-28      9.0
# 58 2023-05-29   2292.0
# 59 2023-05-30  32798.0
# 60 2023-05-31  18897.0
#
# [61 rows x 2 columns]

# %%
# 5월 12일부터 5월 31일까지의 데이터 필터링
may_late_period = ss_04_05_D[(ss_04_05_D['날짜'] >= '2023-05-12') & (ss_04_05_D['날짜'] <= '2023-05-31')]

# 4월 23일부터 5월 11일까지의 데이터 필터링
april_to_may_early_period = ss_04_05_D[(ss_04_05_D['날짜'] >= '2023-04-23') & (ss_04_05_D['날짜'] <= '2023-05-11')]

# 각 기간의 '디지털/가전' 판매량 합계 계산
may_late_period_sum = may_late_period['디지털/가전'].sum()
april_to_may_early_period_sum = april_to_may_early_period['디지털/가전'].sum()

print(f"5월 12일부터 5월 31일까지의 판매량 합계: {may_late_period_sum}")
print(f"4월 23일부터 5월 11일까지의 판매량 합계: {april_to_may_early_period_sum}")
# Out:
# 5월 12일부터 5월 31일까지의 판매량 합계: 271234.0
# 4월 23일부터 5월 11일까지의 판매량 합계: 266532.0

# %%
ss06 = pd.read_csv("ss06.csv", encoding = 'EUC-KR')
st06 = pd.read_csv("st06.csv", encoding = 'EUC-KR')
ts06 = pd.read_csv("ts06.csv", encoding = 'EUC-KR')

ss06.drop(["SEND_CTPV_CD", "SEND_CTGG_CD", "REC_CTGG_CD", "REC_CTPV_CD"], axis=1, inplace=True)
st06.drop(["SEND_CTPV_CD", "SEND_CTGG_CD", "REC_CTPV_CD"], axis=1, inplace=True)
ts06.drop(["SEND_CTPV_CD", "REC_CTPV_CD","REC_CTGG_CD"], axis=1, inplace=True)

ss06.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "SEND_CTGG_NM" : "발송구",
    "REC_CTPV_NM" : "수령시",
    "REC_CTGG_NM" : "수령구"    
}, inplace = True)

st06.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "SEND_CTGG_NM" : "발송구",
    "REC_CTPV_NM" : "수령시",   
}, inplace = True)

ts06.rename(columns={
    "DL_YMD" : "날짜",
    "SEND_CTPV_NM" : "발송시",
    "REC_CTPV_NM" : "수령시",
    "REC_CTGG_NM" : "수령구"    
}, inplace = True)

ss06.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)
st06.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)
ts06.rename(columns={
    "E_C_01": "가구/인테리어", 
    "E_C_02": "기타", 
    "E_C_03": "도서/음반", 
    "E_C_04": "디지털/가전", 
    "E_C_05": "생활/건강", 
    "E_C_06": "스포츠/레저", 
    "E_C_07": "식품",
    "E_C_08": "출산/육아",
    "E_C_09": "패션의류",
    "E_C_10": "패션잡화",
    "E_C_11": "화장품/미용"
}, inplace=True)

ss06['날짜'] = pd.to_datetime(ss06['날짜'], format='%Y%m%d')
st06['날짜'] = pd.to_datetime(st06['날짜'], format='%Y%m%d')
ts06['날짜'] = pd.to_datetime(ts06['날짜'], format='%Y%m%d')

ss06 = ss06.sort_values(by='날짜')
st06 = st06.sort_values(by='날짜')
ts06 = ts06.sort_values(by='날짜')

ss06_D = ss06[['날짜', '디지털/가전']]
ss06_D = ss06_D.groupby('날짜')['디지털/가전'].sum().reset_index()

# %%
ss06.head()
# Out:
#               날짜    발송시   발송구    수령시   수령구  가구/인테리어  기타  도서/음반  디지털/가전  생활/건강  \
# 14404 2023-06-01  서울특별시  영등포구  서울특별시   노원구        5  66      8      35     41
# 5809  2023-06-01  서울특별시   성북구  서울특별시   광진구       10  47     10      26     46
# 5810  2023-06-01  서울특별시   성북구  서울특별시  동대문구        9  44      7      28     47
# 5811  2023-06-01  서울특별시   성북구  서울특별시   중랑구        8  52      6      21     49
# 5812  2023-06-01  서울특별시   성북구  서울특별시   성북구       13  78     22      31     38
#
#        스포츠/레저  식품  출산/육아  패션의류  패션잡화  화장품/미용
# 14404       5  28      4    63    48      44
# 5809       10  68      6   221    91      29
# 5810        6  59     11   275    89      34
# 5811        7  60      8   264    88      20
# 5812        8  75     13   333    97      31

# %%
ss06_D.head()
# Out:
#           날짜  디지털/가전
# 0 2023-06-01   17978
# 1 2023-06-02   17964
# 2 2023-06-03     946
# 3 2023-06-04      35
# 4 2023-06-05   29097

# %%
ss_04_05_06_D = pd.concat([ss04_D, ss05_D, ss06_D], ignore_index=True)
ss_04_05_06_D
# Out:
#            날짜   디지털/가전
# 0  2023-04-01    954.0
# 1  2023-04-02     20.0
# 2  2023-04-03  31438.0
# 3  2023-04-04  20509.0
# 4  2023-04-05  19422.0
# ..        ...      ...
# 86 2023-06-26  29391.0
# 87 2023-06-27  18535.0
# 88 2023-06-28  17618.0
# 89 2023-06-29  16338.0
# 90 2023-06-30  14607.0
#
# [91 rows x 2 columns]

# %%
may_late_period = ss_04_05_06_D[(ss_04_05_06_D['날짜'] >= '2023-05-12') & (ss_04_05_06_D['날짜'] <= '2023-06-09')]

april_to_may_early_period = ss_04_05_06_D[(ss_04_05_06_D['날짜'] >= '2023-04-14') & (ss_04_05_06_D['날짜'] <= '2023-05-11')]

may_late_period_sum = may_late_period['디지털/가전'].sum()
april_to_may_early_period_sum = april_to_may_early_period['디지털/가전'].sum()

print(f"5월 12일부터 6월 09일까지의 판매량 합계: {may_late_period_sum}")
print(f"4월 14일부터 5월 11일까지의 판매량 합계: {april_to_may_early_period_sum}")
# Out:
# 5월 12일부터 6월 09일까지의 판매량 합계: 400160.0
# 4월 14일부터 5월 11일까지의 판매량 합계: 387287.0

# %%
may_late_period = ss_04_05_06_D[(ss_04_05_06_D['날짜'] >= '2023-05-12') & (ss_04_05_06_D['날짜'] <= '2023-05-25')]

april_to_may_early_period = ss_04_05_06_D[(ss_04_05_06_D['날짜'] >= '2023-04-28') & (ss_04_05_06_D['날짜'] <= '2023-05-11')]

may_late_period_sum = may_late_period['디지털/가전'].sum()
april_to_may_early_period_sum = april_to_may_early_period['디지털/가전'].sum()

print(f"5월 12일부터 6월 09일까지의 판매량 합계: {may_late_period_sum}")
print(f"4월 14일부터 5월 11일까지의 판매량 합계: {april_to_may_early_period_sum}")
# Out:
# 5월 12일부터 6월 09일까지의 판매량 합계: 202250.0
# 4월 14일부터 5월 11일까지의 판매량 합계: 181971.0

# %%
import matplotlib.pyplot as plt

# 판매량 데이터 준비
periods = ['5월 12일 - 5월 25일', '4월 28일 - 5월 11일']
sales = [may_late_period_sum, april_to_may_early_period_sum]

# 막대 그래프를 그릴 준비
fig, ax = plt.subplots(figsize=(8, 6))

# 막대 그래프 생성
ax.bar(periods, sales, color=['blue', 'orange'])

# 타이틀 및 라벨 설정
ax.set_title('기간별 디지털/가전 판매량 비교')
ax.set_xlabel('기간')
ax.set_ylabel('판매량')

# 그래프에 값 표시
for i, v in enumerate(sales):
    ax.text(i, v + 3, str(v), color='black', ha='center')

# 그래프를 화면에 표시
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 판매량 데이터 준비
periods = ['5월 12일 - 5월 25일', '4월 28일 - 5월 11일']
sales = [may_late_period_sum, april_to_may_early_period_sum]

# 막대 그래프를 그릴 준비
fig, ax = plt.subplots(figsize=(8, 6))

# 막대 그래프 생성
ax.bar(periods, sales, color=['blue', 'orange'])

# 타이틀 및 라벨 설정
ax.set_title('기간별 디지털/가전 판매량 비교')
ax.set_xlabel('기간')
ax.set_ylabel('판매량')

# y축의 범위를 150000부터 210000까지로 설정하여 확대 효과를 줍니다.
ax.set_ylim(150000, 210000)

# 그래프에 값 표시
for i, v in enumerate(sales):
    # 값이 확대된 범위 안에 있는 경우에만 표시합니다.
    if 150000 <= v <= 210000:
        ax.text(i, v + 500, str(v), color='black', ha='center')

# 그래프를 화면에 표시
plt.tight_layout()
plt.show()
