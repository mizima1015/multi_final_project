# %%
from google.colab import drive
from google.colab import files
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/final'

# %%
send_ml = pd.read_csv(DATA_PATH + '/mldata_send_ver1.csv', low_memory = False)
rec_ml = pd.read_csv(DATA_PATH + '/mldata_rec_ver1.csv', low_memory = False)
oil = pd.read_csv(DATA_PATH + '/석유류+소비량(구별)_20231114093319.csv')

# %%
oil.head()
# Out:
#   자치구별(1) 자치구별(2)     소계   휘발유   등유    경유 벙커C유   LPG     기타
# 0      합계      소계  33479  9070  264  7353    -  6381  10411
# 1      합계     종로구    259    69   10    75    -    43     62
# 2      합계      중구    253    81   21    54    -    53     44
# 3      합계     용산구    263   127    6   102    -    16     12
# 4      합계     성동구    879   292   34   280    -   272      1

# %%
oil
# Out:
#    자치구별(1) 자치구별(2)     소계   휘발유   등유    경유 벙커C유   LPG     기타
# 0       합계      소계  33479  9070  264  7353    -  6381  10411
# 1       합계     종로구    259    69   10    75    -    43     62
# 2       합계      중구    253    81   21    54    -    53     44
# 3       합계     용산구    263   127    6   102    -    16     12
# 4       합계     성동구    879   292   34   280    -   272      1
# 5       합계     광진구    850   403    2   286    -   158      1
# 6       합계    동대문구    868   281   18   259    -   309      0
# 7       합계     중랑구    784   264   10   271    -   238      0
# 8       합계     성북구   1097   532   49   372    -   143      0
# 9       합계     강북구    624   211    2   175    -   235      0
# 10      합계     도봉구    716   312    3   244    -   156      1
# 11      합계     노원구    831   257    2   173    -   398      1
# 12      합계     은평구    717   296    7   209    -   204      1
# 13      합계    서대문구    683   268    2   139    -   273      1
# ...

# %%
oil = oil.drop(['자치구별(1)', '벙커C유'], axis = 1)
oil.head()
# Out:
#   자치구별(2)     소계   휘발유   등유    경유   LPG     기타
# 0      소계  33479  9070  264  7353  6381  10411
# 1     종로구    259    69   10    75    43     62
# 2      중구    253    81   21    54    53     44
# 3     용산구    263   127    6   102    16     12
# 4     성동구    879   292   34   280   272      1

# %%
oil = oil.iloc[1:]
oil.head()
# Out:
#   자치구별(2)   소계  휘발유  등유   경유  LPG  기타
# 1     종로구  259   69  10   75   43  62
# 2      중구  253   81  21   54   53  44
# 3     용산구  263  127   6  102   16  12
# 4     성동구  879  292  34  280  272   1
# 5     광진구  850  403   2  286  158   1

# %%
columns = {'소계' : 'TOTAL_OIL',
           '휘발유' : 'GASOLINE',
           '등유' : 'KEROSENE',
           '경유' : 'DIESEL',
           '기타' : 'OTHER_OIL'}
oil = oil.rename(columns = columns)
oil.head()
# Out:
#   자치구별(2)  TOTAL_OIL  GASOLINE  KEROSENE  DIESEL  LPG  OTHER_OIL
# 1     종로구        259        69        10      75   43         62
# 2      중구        253        81        21      54   53         44
# 3     용산구        263       127         6     102   16         12
# 4     성동구        879       292        34     280  272          1
# 5     광진구        850       403         2     286  158          1

# %%
oil_send = oil.rename(columns = {'자치구별(2)' : 'SEND_GU'})
oil_rec = oil.rename(columns = {'자치구별(2)' : 'REC_GU'})

# %%
oil_send
# Out:
#    SEND_GU  TOTAL_OIL  GASOLINE  KEROSENE  DIESEL  LPG  OTHER_OIL
# 1      종로구        259        69        10      75   43         62
# 2       중구        253        81        21      54   53         44
# 3      용산구        263       127         6     102   16         12
# 4      성동구        879       292        34     280  272          1
# 5      광진구        850       403         2     286  158          1
# 6     동대문구        868       281        18     259  309          0
# 7      중랑구        784       264        10     271  238          0
# 8      성북구       1097       532        49     372  143          0
# 9      강북구        624       211         2     175  235          0
# 10     도봉구        716       312         3     244  156          1
# 11     노원구        831       257         2     173  398          1
# 12     은평구        717       296         7     209  204          1
# 13    서대문구        683       268         2     139  273          1
# ...

# %%
oil_rec
# Out:
#    REC_GU  TOTAL_OIL  GASOLINE  KEROSENE  DIESEL  LPG  OTHER_OIL
# 1     종로구        259        69        10      75   43         62
# 2      중구        253        81        21      54   53         44
# 3     용산구        263       127         6     102   16         12
# 4     성동구        879       292        34     280  272          1
# 5     광진구        850       403         2     286  158          1
# 6    동대문구        868       281        18     259  309          0
# 7     중랑구        784       264        10     271  238          0
# 8     성북구       1097       532        49     372  143          0
# 9     강북구        624       211         2     175  235          0
# 10    도봉구        716       312         3     244  156          1
# 11    노원구        831       257         2     173  398          1
# 12    은평구        717       296         7     209  204          1
# 13   서대문구        683       268         2     139  273          1
# ...

# %%
send_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924411 entries, 0 to 924410
# Data columns (total 42 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DATE                  924411 non-null  object
#  1   YEAR                  924411 non-null  int64
#  2   MONTH                 924411 non-null  int64
#  3   DAY                   924411 non-null  int64
#  4   DAY_OF                924411 non-null  object
#  5   HOLIDAY               924411 non-null  int64
#  6   SEND_CITY             924411 non-null  object
#  7   SEND_GU               924411 non-null  object
#  8   REC_CITY              924411 non-null  object
#  9   REC_GU                559074 non-null  object
#  10  SUB_NAME              924411 non-null  object
#  11  FURNITURE/INTERIOR    924411 non-null  float64
#  12  ETC                   924411 non-null  float64
#  13  BOOK/ALBUM            924411 non-null  float64
# ...

# %%
send_ver2 = send_ml.merge(oil_send, on='SEND_GU')
rec_ver2 = rec_ml.merge(oil_rec, on='REC_GU')

# %%
send_ver2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 924411 entries, 0 to 924410
# Data columns (total 48 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DATE                  924411 non-null  object
#  1   YEAR                  924411 non-null  int64
#  2   MONTH                 924411 non-null  int64
#  3   DAY                   924411 non-null  int64
#  4   DAY_OF                924411 non-null  object
#  5   HOLIDAY               924411 non-null  int64
#  6   SEND_CITY             924411 non-null  object
#  7   SEND_GU               924411 non-null  object
#  8   REC_CITY              924411 non-null  object
#  9   REC_GU                559074 non-null  object
#  10  SUB_NAME              924411 non-null  object
#  11  FURNITURE/INTERIOR    924411 non-null  float64
#  12  ETC                   924411 non-null  float64
#  13  BOOK/ALBUM            924411 non-null  float64
# ...

# %%
rec_ver2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 939171 entries, 0 to 939170
# Data columns (total 48 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DATE                  939171 non-null  object
#  1   YEAR                  939171 non-null  int64
#  2   MONTH                 939171 non-null  int64
#  3   DAY                   939171 non-null  int64
#  4   DAY_OF                939171 non-null  object
#  5   holiday               939171 non-null  int64
#  6   SEND_CITY             939171 non-null  object
#  7   SEND_GU               559074 non-null  object
#  8   REC_CITY              939171 non-null  object
#  9   REC_GU                939171 non-null  object
#  10  SUB_NAME              939171 non-null  object
#  11  FURNITURE/INTERIOR    939171 non-null  float64
#  12  ETC                   939171 non-null  float64
#  13  BOOK/ALBUM            939171 non-null  float64
# ...

# %%
#send_ver2.to_csv('send_ml_ver2.csv', index=False)
#rec_ver2.to_csv('rec_ml_ver2.csv', index=False)

# %%
#files.download('send_ml_ver2.csv')

# %%
#files.download('rec_ml_ver2.csv')
