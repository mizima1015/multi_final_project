# %% [markdown]
# # 라이브러리 설치

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 한글 시각화 준비

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.figure(figsize=(4,3))
plt.plot([-1, 0, 1, 2])
plt.xlabel('간단한 그래프')
plt.show()

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 30)

# %% [markdown]
# # 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝트/파이널프로젝트/데이터 모음/전처리 1차/2022년 물류+허브+구당 인구비+소득_수정.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9094 entries, 0 to 9093
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   배송년월일         9094 non-null   object
#  1   년             9094 non-null   int64
#  2   월             9094 non-null   int64
#  3   일             9094 non-null   int64
#  4   요일            9094 non-null   object
#  5   공휴일           9094 non-null   int64
#  6   담당지역          9094 non-null   object
#  7   터미널이름         9094 non-null   object
#  8   가구/인테리어       9094 non-null   float64
#  9   기타            9094 non-null   float64
#  10  도서/음반         9094 non-null   float64
#  11  디지털/가전        9094 non-null   float64
#  12  생활/건강         9094 non-null   float64
#  13  스포츠/레저        9094 non-null   float64
#  14  식품            9094 non-null   float64
#  15  출산/육아         9094 non-null   float64
#  16  패션의류          9094 non-null   float64
#  17  패션잡화          9094 non-null   float64
#  18  화장품/미용        9094 non-null   float64
#  19  총 인구          9094 non-null   int64
#  20  20대 미만 비율     9094 non-null   float64
#  21  20-30대 비율     9094 non-null   float64
#  22  40-50대 비율     9094 non-null   float64
#  23  60-70대 비율     9094 non-null   float64
#  24  80대 이상 비율     9094 non-null   float64
#  25  소득2천만원주민비율    9094 non-null   float64
#  26  소득3천만원주민비율    9094 non-null   float64
#  27  소득4천만원주민비율    9094 non-null   float64
#  28  소득5천만원주민비율    9094 non-null   float64
#  29  소득6천만원주민비율    9094 non-null   float64
#  30  소득7천만원주민비율    9094 non-null   float64
#  31  소득7천만원이상주민비율  9094 non-null   float64
# dtypes: float64(23), int64(5), object(4)
# memory usage: 2.2+ MB

# %%
df.columns
# Out:
# Index(['배송년월일', '년', '월', '일', '요일', '공휴일', '담당지역', '터미널이름', '가구/인테리어', '기타',
#        '도서/음반', '디지털/가전', '생활/건강', '스포츠/레저', '식품', '출산/육아', '패션의류', '패션잡화',
#        '화장품/미용', '총 인구', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율',
#        '80대 이상 비율', '소득2천만원주민비율', '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율',
#        '소득6천만원주민비율', '소득7천만원주민비율', '소득7천만원이상주민비율'],
#       dtype='object')

# %% [markdown]
# # 데이터 전처리하기

# %% [markdown]
# ## 지역별 품목별 택배물량 합

# %%
region = df[['담당지역', '터미널이름', '가구/인테리어', '기타', '도서/음반', '디지털/가전', '생활/건강', '스포츠/레저', '식품', '출산/육아', '패션의류', '패션잡화', '화장품/미용']]
region = region.groupby(['담당지역', '터미널이름']).sum().reset_index()
region['총 물량'] = region.iloc[:, 2:].sum(axis=1)
region.sort_values(by='총 물량', ascending=False)
# Out:
# 6    620487.0  117271.0   442541.0   81651.0  1128072.0   346081.0   315251.0
# 24   571709.0  144181.0   630253.0   96393.0  1158400.0   419456.0   285289.0
# 4    508022.0   73875.0   456168.0   49713.0  1091946.0   443283.0   502506.0
# 1    576957.0   89449.0   613361.0   76653.0   924495.0   463190.0   255839.0
# 5    540437.0   94341.0   387527.0   73687.0  1165164.0   529353.0   271945.0
# 8    643474.0   95503.0   546460.0  110181.0  1085598.0   345424.0   248797.0
# 11   600883.0   77686.0   425621.0   67272.0   908987.0   332364.0   298168.0
# 18   493697.0   81376.0   445332.0   55564.0   876427.0   436137.0   276633.0
# 21   535629.0  106094.0   509032.0   60725.0   793369.0   348665.0   404965.0
# 22   398065.0   43455.0   308392.0   45696.0  1077424.0   375388.0   164312.0
# 13   430393.0   62456.0   375479.0  109667.0   856123.0   335073.0   234026.0
# 9    364502.0   71928.0   425734.0   47346.0   915579.0   277380.0   224974.0
# 2    276236.0   33420.0   232178.0   41340.0   817495.0   264259.0   139513.0
#
#           총 물량
# 0   12220820.0
# 3    8428150.0
# 12   7816646.0
# 17   7515413.0
# 16   7496446.0
# 15   7273990.0
# 7    6711993.0
# 14   6512820.0
# 19   6080829.0
# 20   5443527.0
# 23   5183977.0
# 10   5158400.0
# 6    4902477.0
# 24   4782931.0
# 4    4701903.0
# 1    4604727.0
# 5    4570976.0
# 8    4388910.0
# 11   4094580.0
# 18   4078446.0
# 21   3991035.0
# 22   3714047.0
# 13   3591148.0
# 9    3324661.0
# 2    2627148.0

# %% [markdown]
# ## 지역별 소득수준별 택배 물량 평균

# %%
income = df[['담당지역', '소득2천만원주민비율', '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율', '소득6천만원주민비율', '소득7천만원주민비율', '소득7천만원이상주민비율']]
income = income.groupby(['담당지역']).mean().reset_index()
income.sort_values(by='소득7천만원이상주민비율', ascending=False)
# Out:
#     담당지역  소득2천만원주민비율  소득3천만원주민비율  소득4천만원주민비율  소득5천만원주민비율  소득6천만원주민비율  \
# 0    강남구        0.09        0.28        0.21        0.13        0.07
# 14   서초구        0.08        0.27        0.22        0.13        0.08
# 17   송파구        0.09        0.30        0.25        0.13        0.07
# 18   양천구        0.11        0.32        0.24        0.12        0.06
# 20   용산구        0.11        0.36        0.22        0.12        0.06
# 15   성동구        0.11        0.35        0.23        0.12        0.06
# 12   마포구        0.12        0.34        0.23        0.12        0.06
# 11   동작구        0.12        0.35        0.24        0.12        0.06
# 1    강동구        0.10        0.34        0.26        0.13        0.06
# 19  영등포구        0.12        0.38        0.23        0.11        0.06
# 22   종로구        0.15        0.39        0.21        0.10        0.05
# 13  서대문구        0.14        0.38        0.22        0.11        0.05
# 3    강서구        0.11        0.34        0.26        0.13        0.06
# 16   성북구        0.15        0.37        0.23        0.11        0.05
# 8    노원구        0.13        0.34        0.25        0.12        0.06
# 23    중구        0.15        0.40        0.20        0.10        0.05
# 5    광진구        0.13        0.38        0.24        0.11        0.05
# 10  동대문구        0.16        0.40        0.22        0.10        0.05
# 6    구로구        0.13        0.39        0.24        0.11        0.05
# 21   은평구        0.12        0.36        0.26        0.12        0.06
# 9    도봉구        0.13        0.37        0.26        0.11        0.05
# 4    관악구        0.12        0.40        0.26        0.11        0.05
# 7    금천구        0.14        0.41        0.25        0.11        0.05
# 24   중랑구        0.12        0.39        0.27        0.11        0.05
# 2    강북구        0.14        0.41        0.25        0.10        0.04
#
#     소득7천만원주민비율  소득7천만원이상주민비율
# 0         0.05          0.18
# 14        0.05          0.18
# 17        0.04          0.12
# 18        0.04          0.11
# 20        0.04          0.10
# 15        0.04          0.10
# 12        0.04          0.10
# 11        0.03          0.08
# 1         0.04          0.08
# 19        0.03          0.08
# 22        0.03          0.07
# 13        0.03          0.07
# 3         0.04          0.07
# 16        0.03          0.06
# 8         0.03          0.06
# 23        0.03          0.06
# 5         0.03          0.06
# 10        0.03          0.05
# 6         0.03          0.05
# 21        0.03          0.05
# 9         0.03          0.04
# 4         0.02          0.04
# 7         0.02          0.03
# 24        0.02          0.03
# 2         0.02          0.03

# %% [markdown]
# ## 지역별 인구별 택배 물량 평균

# %%
ppl = df[['담당지역', '총 인구', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']]
ppl = ppl.groupby(['담당지역']).mean().reset_index()
ppl.sort_values(by='40-50대 비율', ascending=False)
# Out:
#     담당지역      총 인구  20대 미만 비율  20-30대 비율  40-50대 비율  60-70대 비율  80대 이상 비율
# 18   양천구  444010.0      17.12      24.82      33.97      20.91       3.18
# 0    강남구  534103.0      17.36      27.47      33.83      18.32       3.01
# 14   서초구  408451.0      18.16      26.61      33.70      18.42       3.11
# 8    노원구  508014.0      15.31      26.11      32.62      21.72       4.25
# 21   은평구  470602.0      13.30      27.78      31.86      22.64       4.42
# 17   송파구  664514.0      15.79      29.42      31.84      20.10       2.86
# 6    구로구  418418.0      13.18      28.77      31.84      22.56       3.65
# 9    도봉구  313989.0      12.52      25.16      31.79      25.58       4.95
# 1    강동구  464037.0      15.51      27.81      31.69      21.91       3.07
# 2    강북구  297702.0      11.16      26.24      31.54      25.87       5.19
# 24   중랑구  390140.0      11.73      28.82      31.26      24.17       4.03
# 20   용산구  233284.0      12.32      32.51      31.21      19.57       4.39
# 16   성북구  441984.0      14.34      29.74      31.17      20.51       4.24
# 7    금천구  242818.0      10.52      31.77      31.15      22.94       3.61
# 15   성동구  288234.0      12.96      32.07      30.79      20.38       3.81
# 12   마포구  375585.0      13.33      34.73      30.72      17.45       3.77
# 19  영등포구  398085.0      12.35      33.43      30.58      19.95       3.69
# 22   종로구  152211.0      11.61      31.93      30.41      21.17       4.88
# 3    강서구  574638.0      13.42      31.80      30.15      21.20       3.42
# 5    광진구  351252.0      12.08      35.10      30.07      19.43       3.33
# 13  서대문구  319554.0      13.20      32.11      29.96      20.21       4.53
# 23    중구  130785.0      10.26      33.07      29.68      22.21       4.78
# 11   동작구  390432.0      12.49      33.27      29.56      20.74       3.94
# 10  동대문구  353601.0      12.07      33.37      28.83      21.50       4.22
# 4    관악구  501226.0       9.09      40.93      26.78      19.66       3.54

# %% [markdown]
# ## 지역별, 소득수준별, 인구별 데이터 합치기

# %%
region_income_ppl = pd.merge(pd.merge(region, income, on='담당지역', how='inner'), ppl, on='담당지역', how='inner')
region_income_ppl
# Out:
#     담당지역            터미널이름   가구/인테리어         기타     도서/음반     디지털/가전  \
# 0    강남구  강남ASub & 강남BSub  275242.0  2525106.0  595718.0   721765.0
# 1    강동구          강동A Sub  126989.0   957883.0  182096.0   337815.0
# 2    강북구            강북Sub   49009.0   536268.0   73171.0   164259.0
# 3    강서구  강서ASub & 강서BSub  182715.0  1562369.0  326254.0   692447.0
# 4    관악구           관악1Sub   96379.0   905153.0  231312.0   343546.0
# 5    광진구  광진BSub & 광진ASub   98827.0   904223.0  140166.0   365306.0
# 6    구로구            구로Sub  114215.0  1101256.0  184337.0   451315.0
# 7    금천구            금천Sub  175520.0  1106367.0  192779.0   558107.0
# 8    노원구            노원Sub   89246.0   787559.0  143810.0   292858.0
# 9    도봉구            도봉Sub   74136.0   566456.0   80054.0   276572.0
# 10  동대문구           동대문Sub  126090.0  1027426.0  176584.0   275212.0
# 11   동작구  동작ASub & 동작BSub   98245.0   768741.0  229935.0   286678.0
# 12   마포구            마포Sub  155868.0  1722815.0  364853.0   831976.0
# 13  서대문구           서대문Sub   52244.0   723726.0  144329.0   267632.0
# 14   서초구  서초ASub & 서초BSub  160972.0  1545277.0  406367.0   441927.0
# 15   성동구  성동ASub & 성동BSub  138045.0  1882368.0  276955.0   476059.0
# 16   성북구  성북ASub & 성북BSub  111893.0  1403876.0  170315.0   356459.0
# 17   송파구          송파C Sub  136375.0  1568109.0  276397.0   530131.0
# 18   양천구            양천Sub   66439.0   863235.0  150537.0   333069.0
# 19  영등포구           영등포Sub  119114.0  1450337.0  273124.0   545846.0
# 20   용산구            용산Sub   75742.0  1036766.0  164546.0  1890409.0
# 21   은평구            은평Sub   87852.0   754949.0  129398.0   260357.0
# 22   종로구  종로ASub & 종로BSub   86136.0   784045.0  210517.0   220617.0
# 23    중구            중구Sub  113095.0  1169301.0  191336.0   219967.0
# 24   중랑구            중랑Sub  107456.0   958839.0  127204.0   283751.0
#
#         생활/건강    스포츠/레저         식품     출산/육아       패션의류       패션잡화     화장품/미용  \
# 0   1341723.0  185921.0  1290945.0  147049.0  3028440.0  1034021.0  1074890.0
# 1    576957.0   89449.0   613361.0   76653.0   924495.0   463190.0   255839.0
# 2    276236.0   33420.0   232178.0   41340.0   817495.0   264259.0   139513.0
# 3    977790.0  184530.0  1073682.0  168926.0  1751693.0   700831.0   806913.0
# 4    508022.0   73875.0   456168.0   49713.0  1091946.0   443283.0   502506.0
# 5    540437.0   94341.0   387527.0   73687.0  1165164.0   529353.0   271945.0
# 6    620487.0  117271.0   442541.0   81651.0  1128072.0   346081.0   315251.0
# 7    680519.0  224557.0   616589.0  155519.0  1551027.0   706171.0   744838.0
# 출산/육아          0.179808  -0.269332  -0.407269
# 패션의류           0.132930  -0.353034  -0.329804
# 패션잡화           0.149429  -0.440964  -0.493284
# 화장품/미용         0.172375  -0.361781  -0.583576
# 총 물량           0.236169  -0.565534  -0.564470
# 소득2천만원주민비율    -0.495147   0.418006   0.718576
# 소득3천만원주민비율    -0.648275   0.536267   0.620454
# 소득4천만원주민비율    -0.017132   0.490394  -0.148223
# 소득5천만원주민비율     0.489280  -0.454014  -0.710422
# 소득6천만원주민비율     0.513992  -0.609201  -0.649743
# 소득7천만원주민비율     0.536316  -0.618505  -0.529170
# 소득7천만원이상주민비율   0.536399  -0.701826  -0.564985
# 총 인구           0.231302  -0.239931  -0.647376
# 20대 미만 비율      0.801044  -0.373217  -0.546656
# 20-30대 비율     -0.875174  -0.437754  -0.049017
# 40-50대 비율      1.000000   0.032155  -0.253958
# 60-70대 비율      0.032155   1.000000   0.562518
# 80대 이상 비율     -0.253958   0.562518   1.000000

# %% [markdown]
# ## 상관관계 히트맵 시각화

# %%
heatmap = region_income_ppl.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(heatmap, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('region_income_ppl Heatmap')
plt.show()

# %% [markdown]
# ## 결과 해석
# 소득5천만원을 기준으로 각 품목별 총 택배물량과의 상관관계가 뚜렷하게 나눠짐.
#
# <양의 상관관계>
# - 총 물량, 소득수준이 높아질수록 양의 상관관계가 점점 강해짐.
# - 5천만원주민비율 ~ 7천만원이상주민비율 : 대부분의 품목에서 양의 상관관계
#   - 가구/인테리어,기타, 도서음반, 생활건강, 식품
#   - 소득7천만원이상 주민비율과 도서/음반과의 양의 관계가 가장 강함. (0.8)
# - 다만, 품목 중에서 출산/육아는 높은 소득 수준 지역에서 상대적으로 약한 상관관계를 보임.
#
# <음의 상관관계>
# - 총 물량, 소득수준이 2천만원~4천만원 수준에서는 음의 상관관계. (3천만원 일 때 가장 강한 음의 상관관계를 보임)
# - 품목 중에서는 도서/음반, 생활/건강, 식품에서 강한 음의 상관관계
#
#
#
# ---
#
#
#
# 총 인구, 총 물량 사이에 양의 상관관계
# - 지역의 총 인구가 물량에 어느정도 영향을 미침.
#
# - 20대 미만 비율이 높은 지역 : 총 물량, 품목 대체로 양의 상관관계.
# - 40~50대 비율이 높은 지역 : 20대 만큼은 아니지만 약한 양의 상관관계
# - 60~70, 80대이상 비율이 높은 지역 : 대체로 총물량에서는 강한 음의 상관관계.

# %% [markdown]
# ## 가설검정 (유의미한 상관계수인지 판단하기 위함)

# %%
from scipy import stats
import pandas as pd

# 상관계수 행렬
correlation_matrix = region_income_ppl.corr()

# 유의수준 설정
alpha = 0.05  # 95% 신뢰수준

# 상관계수와 p-value를 저장할 데이터프레임 생성
correlation_results = pd.DataFrame(index=correlation_matrix.columns, columns=correlation_matrix.columns)

significant_correlations = []
insignificant_correlations = []

# 각 상관계수의 유의성 검정
for col1 in correlation_matrix.columns:
    for col2 in correlation_matrix.columns:
        if col1 != col2:
            r, p = stats.pearsonr(region_income_ppl[col1], region_income_ppl[col2])
            correlation_results.at[col1, col2] = (r, p)
            if p < alpha:
                print(f"{col1}:{col2} 유의미함.")
                significant_correlations.append((col1, col2))
            else:
                print(f"{col1}:{col2} 유의미하지 않음.")
                insignificant_correlations.append((col1, col2))

significant_df = pd.DataFrame(significant_correlations, columns=["Variable1", "Variable2"])
insignificant_df = pd.DataFrame(insignificant_correlations, columns=["Variable1", "Variable2"])
# Out:
# 가구/인테리어:기타 유의미함.
# 가구/인테리어:도서/음반 유의미함.
# 가구/인테리어:디지털/가전 유의미하지 않음.
# 가구/인테리어:생활/건강 유의미함.
# 가구/인테리어:스포츠/레저 유의미함.
# 가구/인테리어:식품 유의미함.
# 가구/인테리어:출산/육아 유의미함.
# 가구/인테리어:패션의류 유의미함.
# 가구/인테리어:패션잡화 유의미함.
# 가구/인테리어:화장품/미용 유의미함.
# 가구/인테리어:총 물량 유의미함.
# 가구/인테리어:소득2천만원주민비율 유의미함.
# 가구/인테리어:소득3천만원주민비율 유의미함.
# 가구/인테리어:소득4천만원주민비율 유의미하지 않음.
# 가구/인테리어:소득5천만원주민비율 유의미함.
# 가구/인테리어:소득6천만원주민비율 유의미함.
# 가구/인테리어:소득7천만원주민비율 유의미함.
# 가구/인테리어:소득7천만원이상주민비율 유의미함.
# 가구/인테리어:총 인구 유의미하지 않음.
# 가구/인테리어:20대 미만 비율 유의미하지 않음.
# 가구/인테리어:20-30대 비율 유의미하지 않음.
# 가구/인테리어:40-50대 비율 유의미하지 않음.
# 가구/인테리어:60-70대 비율 유의미함.
# 가구/인테리어:80대 이상 비율 유의미함.
# 기타:가구/인테리어 유의미함.
# 기타:도서/음반 유의미함.
# 기타:디지털/가전 유의미하지 않음.
# 기타:생활/건강 유의미함.
# 기타:스포츠/레저 유의미함.
# 기타:식품 유의미함.
# 기타:출산/육아 유의미함.
# 기타:패션의류 유의미함.
# 기타:패션잡화 유의미함.
# 기타:화장품/미용 유의미함.
# 기타:총 물량 유의미함.
# 기타:소득2천만원주민비율 유의미함.
# 기타:소득3천만원주민비율 유의미함.
# 기타:소득4천만원주민비율 유의미하지 않음.
# 기타:소득5천만원주민비율 유의미함.
# 기타:소득6천만원주민비율 유의미함.
# 기타:소득7천만원주민비율 유의미함.
# 기타:소득7천만원이상주민비율 유의미함.
# 기타:총 인구 유의미하지 않음.
# 기타:20대 미만 비율 유의미함.
# 기타:20-30대 비율 유의미하지 않음.
# 기타:40-50대 비율 유의미하지 않음.
# 기타:60-70대 비율 유의미함.
# 기타:80대 이상 비율 유의미함.
# 도서/음반:가구/인테리어 유의미함.
# 도서/음반:기타 유의미함.
# 도서/음반:디지털/가전 유의미하지 않음.
# 도서/음반:생활/건강 유의미함.
# 도서/음반:스포츠/레저 유의미함.
# 도서/음반:식품 유의미함.
# 도서/음반:출산/육아 유의미함.
# 도서/음반:패션의류 유의미함.
# 도서/음반:패션잡화 유의미함.
# 도서/음반:화장품/미용 유의미함.
# 도서/음반:총 물량 유의미함.
# 도서/음반:소득2천만원주민비율 유의미함.
# 도서/음반:소득3천만원주민비율 유의미함.
# 도서/음반:소득4천만원주민비율 유의미하지 않음.
# 도서/음반:소득5천만원주민비율 유의미함.
# 도서/음반:소득6천만원주민비율 유의미함.
# 도서/음반:소득7천만원주민비율 유의미함.
# 도서/음반:소득7천만원이상주민비율 유의미함.
# 도서/음반:총 인구 유의미하지 않음.
# 도서/음반:20대 미만 비율 유의미함.
# 도서/음반:20-30대 비율 유의미하지 않음.
# 도서/음반:40-50대 비율 유의미하지 않음.
# 도서/음반:60-70대 비율 유의미함.
# 도서/음반:80대 이상 비율 유의미함.
# 디지털/가전:가구/인테리어 유의미하지 않음.
# 디지털/가전:기타 유의미하지 않음.
# 디지털/가전:도서/음반 유의미하지 않음.
# 디지털/가전:생활/건강 유의미하지 않음.
# 디지털/가전:스포츠/레저 유의미하지 않음.
# 디지털/가전:식품 유의미하지 않음.
# 디지털/가전:출산/육아 유의미하지 않음.
# 디지털/가전:패션의류 유의미하지 않음.
# 디지털/가전:패션잡화 유의미하지 않음.
# 디지털/가전:화장품/미용 유의미하지 않음.
# 디지털/가전:총 물량 유의미함.
# 디지털/가전:소득2천만원주민비율 유의미하지 않음.
# 디지털/가전:소득3천만원주민비율 유의미하지 않음.
# 디지털/가전:소득4천만원주민비율 유의미하지 않음.
# 디지털/가전:소득5천만원주민비율 유의미하지 않음.
# 디지털/가전:소득6천만원주민비율 유의미하지 않음.
# 디지털/가전:소득7천만원주민비율 유의미함.
# 디지털/가전:소득7천만원이상주민비율 유의미하지 않음.
# 디지털/가전:총 인구 유의미하지 않음.
# 디지털/가전:20대 미만 비율 유의미하지 않음.
# 디지털/가전:20-30대 비율 유의미하지 않음.
# 디지털/가전:40-50대 비율 유의미하지 않음.
# 디지털/가전:60-70대 비율 유의미함.
# 디지털/가전:80대 이상 비율 유의미하지 않음.
# 생활/건강:가구/인테리어 유의미함.
# 생활/건강:기타 유의미함.
# 생활/건강:도서/음반 유의미함.
# 생활/건강:디지털/가전 유의미하지 않음.
# 생활/건강:스포츠/레저 유의미함.
# 생활/건강:식품 유의미함.
# 생활/건강:출산/육아 유의미함.
# 생활/건강:패션의류 유의미함.
# 생활/건강:패션잡화 유의미함.
# 생활/건강:화장품/미용 유의미함.
# 생활/건강:총 물량 유의미함.
# 생활/건강:소득2천만원주민비율 유의미함.
# 생활/건강:소득3천만원주민비율 유의미함.
# 생활/건강:소득4천만원주민비율 유의미하지 않음.
# 생활/건강:소득5천만원주민비율 유의미함.
# 생활/건강:소득6천만원주민비율 유의미함.
# 생활/건강:소득7천만원주민비율 유의미함.
# 생활/건강:소득7천만원이상주민비율 유의미함.
# 생활/건강:총 인구 유의미함.
# 생활/건강:20대 미만 비율 유의미함.
# 생활/건강:20-30대 비율 유의미하지 않음.
# 생활/건강:40-50대 비율 유의미하지 않음.
# 생활/건강:60-70대 비율 유의미함.
# 생활/건강:80대 이상 비율 유의미함.
# 스포츠/레저:가구/인테리어 유의미함.
# 스포츠/레저:기타 유의미함.
# 스포츠/레저:도서/음반 유의미함.
# 스포츠/레저:디지털/가전 유의미하지 않음.
# 스포츠/레저:생활/건강 유의미함.
# 스포츠/레저:식품 유의미함.
# 스포츠/레저:출산/육아 유의미함.
# 스포츠/레저:패션의류 유의미함.
# 스포츠/레저:패션잡화 유의미함.
# 스포츠/레저:화장품/미용 유의미함.
# 스포츠/레저:총 물량 유의미함.
# 스포츠/레저:소득2천만원주민비율 유의미함.
# 스포츠/레저:소득3천만원주민비율 유의미하지 않음.
# 스포츠/레저:소득4천만원주민비율 유의미하지 않음.
# 스포츠/레저:소득5천만원주민비율 유의미함.
# 스포츠/레저:소득6천만원주민비율 유의미함.
# 스포츠/레저:소득7천만원주민비율 유의미하지 않음.
# 스포츠/레저:소득7천만원이상주민비율 유의미하지 않음.
# 스포츠/레저:총 인구 유의미함.
# 스포츠/레저:20대 미만 비율 유의미하지 않음.
# 스포츠/레저:20-30대 비율 유의미하지 않음.
# 스포츠/레저:40-50대 비율 유의미하지 않음.
# 스포츠/레저:60-70대 비율 유의미하지 않음.
# 스포츠/레저:80대 이상 비율 유의미함.
# 식품:가구/인테리어 유의미함.
# 식품:기타 유의미함.
# 식품:도서/음반 유의미함.
# 식품:디지털/가전 유의미하지 않음.
# 식품:생활/건강 유의미함.
# 식품:스포츠/레저 유의미함.
# 식품:출산/육아 유의미함.
# 식품:패션의류 유의미함.
# 식품:패션잡화 유의미함.
# 식품:화장품/미용 유의미함.
# 식품:총 물량 유의미함.
# 식품:소득2천만원주민비율 유의미함.
# 식품:소득3천만원주민비율 유의미함.
# 식품:소득4천만원주민비율 유의미하지 않음.
# 식품:소득5천만원주민비율 유의미함.
# 식품:소득6천만원주민비율 유의미함.
# 식품:소득7천만원주민비율 유의미함.
# 식품:소득7천만원이상주민비율 유의미함.
# 식품:총 인구 유의미함.
# 식품:20대 미만 비율 유의미함.
# 식품:20-30대 비율 유의미하지 않음.
# 식품:40-50대 비율 유의미하지 않음.
# 식품:60-70대 비율 유의미함.
# 식품:80대 이상 비율 유의미함.
# 출산/육아:가구/인테리어 유의미함.
# 출산/육아:기타 유의미함.
# 출산/육아:도서/음반 유의미함.
# 출산/육아:디지털/가전 유의미하지 않음.
# 출산/육아:생활/건강 유의미함.
# 출산/육아:스포츠/레저 유의미함.
# 출산/육아:식품 유의미함.
# 출산/육아:패션의류 유의미함.
# 출산/육아:패션잡화 유의미함.
# 출산/육아:화장품/미용 유의미함.
# 출산/육아:총 물량 유의미함.
# 출산/육아:소득2천만원주민비율 유의미하지 않음.
# 출산/육아:소득3천만원주민비율 유의미하지 않음.
# 출산/육아:소득4천만원주민비율 유의미하지 않음.
# 출산/육아:소득5천만원주민비율 유의미하지 않음.
# 출산/육아:소득6천만원주민비율 유의미하지 않음.
# 출산/육아:소득7천만원주민비율 유의미하지 않음.
# 출산/육아:소득7천만원이상주민비율 유의미하지 않음.
# 출산/육아:총 인구 유의미함.
# 출산/육아:20대 미만 비율 유의미하지 않음.
# 출산/육아:20-30대 비율 유의미하지 않음.
# 출산/육아:40-50대 비율 유의미하지 않음.
# 출산/육아:60-70대 비율 유의미하지 않음.
# 출산/육아:80대 이상 비율 유의미함.
# 패션의류:가구/인테리어 유의미함.
# 패션의류:기타 유의미함.
# 패션의류:도서/음반 유의미함.
# 패션의류:디지털/가전 유의미하지 않음.
# 패션의류:생활/건강 유의미함.
# 패션의류:스포츠/레저 유의미함.
# 패션의류:식품 유의미함.
# 패션의류:출산/육아 유의미함.
# 패션의류:패션잡화 유의미함.
# 패션의류:화장품/미용 유의미함.
# 패션의류:총 물량 유의미함.
# 패션의류:소득2천만원주민비율 유의미하지 않음.
# 패션의류:소득3천만원주민비율 유의미하지 않음.
# 패션의류:소득4천만원주민비율 유의미하지 않음.
# 패션의류:소득5천만원주민비율 유의미하지 않음.
# 패션의류:소득6천만원주민비율 유의미하지 않음.
# 패션의류:소득7천만원주민비율 유의미하지 않음.
# 패션의류:소득7천만원이상주민비율 유의미함.
# 패션의류:총 인구 유의미하지 않음.
# 패션의류:20대 미만 비율 유의미하지 않음.
# 패션의류:20-30대 비율 유의미하지 않음.
# 패션의류:40-50대 비율 유의미하지 않음.
# 패션의류:60-70대 비율 유의미하지 않음.
# 패션의류:80대 이상 비율 유의미하지 않음.
# 패션잡화:가구/인테리어 유의미함.
# 패션잡화:기타 유의미함.
# 패션잡화:도서/음반 유의미함.
# 패션잡화:디지털/가전 유의미하지 않음.
# 패션잡화:생활/건강 유의미함.
# 패션잡화:스포츠/레저 유의미함.
# 패션잡화:식품 유의미함.
# 패션잡화:출산/육아 유의미함.
# 패션잡화:패션의류 유의미함.
# 패션잡화:화장품/미용 유의미함.
# 패션잡화:총 물량 유의미함.
# 패션잡화:소득2천만원주민비율 유의미하지 않음.
# 패션잡화:소득3천만원주민비율 유의미하지 않음.
# 패션잡화:소득4천만원주민비율 유의미하지 않음.
# 패션잡화:소득5천만원주민비율 유의미하지 않음.
# 패션잡화:소득6천만원주민비율 유의미하지 않음.
# 패션잡화:소득7천만원주민비율 유의미함.
# 패션잡화:소득7천만원이상주민비율 유의미함.
# 패션잡화:총 인구 유의미하지 않음.
# 패션잡화:20대 미만 비율 유의미하지 않음.
# 패션잡화:20-30대 비율 유의미하지 않음.
# 패션잡화:40-50대 비율 유의미하지 않음.
# 패션잡화:60-70대 비율 유의미함.
# 패션잡화:80대 이상 비율 유의미함.
# 화장품/미용:가구/인테리어 유의미함.
# 화장품/미용:기타 유의미함.
# 화장품/미용:도서/음반 유의미함.
# 화장품/미용:디지털/가전 유의미하지 않음.
# 화장품/미용:생활/건강 유의미함.
# 화장품/미용:스포츠/레저 유의미함.
# 화장품/미용:식품 유의미함.
# 화장품/미용:출산/육아 유의미함.
# 화장품/미용:패션의류 유의미함.
# 화장품/미용:패션잡화 유의미함.
# 화장품/미용:총 물량 유의미함.
# 화장품/미용:소득2천만원주민비율 유의미함.
# 소득7천만원주민비율:소득2천만원주민비율 유의미함.
# 소득7천만원주민비율:소득3천만원주민비율 유의미함.
# 소득7천만원주민비율:소득4천만원주민비율 유의미하지 않음.
# 소득7천만원주민비율:소득5천만원주민비율 유의미함.
# 소득7천만원주민비율:소득6천만원주민비율 유의미함.
# 소득7천만원주민비율:소득7천만원이상주민비율 유의미함.
# 소득7천만원주민비율:총 인구 유의미하지 않음.
# 소득7천만원주민비율:20대 미만 비율 유의미함.
# 소득7천만원주민비율:20-30대 비율 유의미하지 않음.
# 소득7천만원주민비율:40-50대 비율 유의미함.
# 소득7천만원주민비율:60-70대 비율 유의미함.
# 소득7천만원주민비율:80대 이상 비율 유의미함.
# 소득7천만원이상주민비율:가구/인테리어 유의미함.
# 소득7천만원이상주민비율:기타 유의미함.
# 소득7천만원이상주민비율:도서/음반 유의미함.
# 소득7천만원이상주민비율:디지털/가전 유의미하지 않음.
# 소득7천만원이상주민비율:생활/건강 유의미함.
# 소득7천만원이상주민비율:스포츠/레저 유의미하지 않음.
# 소득7천만원이상주민비율:식품 유의미함.
# 소득7천만원이상주민비율:출산/육아 유의미하지 않음.
# 소득7천만원이상주민비율:패션의류 유의미함.
# 소득7천만원이상주민비율:패션잡화 유의미함.
# 소득7천만원이상주민비율:화장품/미용 유의미함.
# 소득7천만원이상주민비율:총 물량 유의미함.
# 소득7천만원이상주민비율:소득2천만원주민비율 유의미함.
# 소득7천만원이상주민비율:소득3천만원주민비율 유의미함.
# 소득7천만원이상주민비율:소득4천만원주민비율 유의미함.
# 소득7천만원이상주민비율:소득5천만원주민비율 유의미함.
# 소득7천만원이상주민비율:소득6천만원주민비율 유의미함.
# 소득7천만원이상주민비율:소득7천만원주민비율 유의미함.
# 소득7천만원이상주민비율:총 인구 유의미하지 않음.
# 소득7천만원이상주민비율:20대 미만 비율 유의미함.
# 소득7천만원이상주민비율:20-30대 비율 유의미하지 않음.
# 소득7천만원이상주민비율:40-50대 비율 유의미함.
# 소득7천만원이상주민비율:60-70대 비율 유의미함.
# 소득7천만원이상주민비율:80대 이상 비율 유의미함.
# 총 인구:가구/인테리어 유의미하지 않음.
# 총 인구:기타 유의미하지 않음.
# 총 인구:도서/음반 유의미하지 않음.
# 총 인구:디지털/가전 유의미하지 않음.
# 총 인구:생활/건강 유의미함.
# 총 인구:스포츠/레저 유의미함.
# 총 인구:식품 유의미함.
# 총 인구:출산/육아 유의미함.
# 총 인구:패션의류 유의미하지 않음.
# 총 인구:패션잡화 유의미하지 않음.
# 총 인구:화장품/미용 유의미함.
# 총 인구:총 물량 유의미하지 않음.
# 총 인구:소득2천만원주민비율 유의미함.
# 총 인구:소득3천만원주민비율 유의미함.
# 총 인구:소득4천만원주민비율 유의미함.
# 총 인구:소득5천만원주민비율 유의미함.
# 총 인구:소득6천만원주민비율 유의미함.
# 총 인구:소득7천만원주민비율 유의미하지 않음.
# 총 인구:소득7천만원이상주민비율 유의미하지 않음.
# 총 인구:20대 미만 비율 유의미함.
# 총 인구:20-30대 비율 유의미하지 않음.
# 총 인구:40-50대 비율 유의미하지 않음.
# 총 인구:60-70대 비율 유의미하지 않음.
# 총 인구:80대 이상 비율 유의미함.
# 20대 미만 비율:가구/인테리어 유의미하지 않음.
# 20대 미만 비율:기타 유의미함.
# 20대 미만 비율:도서/음반 유의미함.
# 20대 미만 비율:디지털/가전 유의미하지 않음.
# 20대 미만 비율:생활/건강 유의미함.
# 20대 미만 비율:스포츠/레저 유의미하지 않음.
# 20대 미만 비율:식품 유의미함.
# 20대 미만 비율:출산/육아 유의미하지 않음.
# 20대 미만 비율:패션의류 유의미하지 않음.
# 20대 미만 비율:패션잡화 유의미하지 않음.
# 20대 미만 비율:화장품/미용 유의미하지 않음.
# 20대 미만 비율:총 물량 유의미함.
# 20대 미만 비율:소득2천만원주민비율 유의미함.
# 20대 미만 비율:소득3천만원주민비율 유의미함.
# 20대 미만 비율:소득4천만원주민비율 유의미하지 않음.
# 20대 미만 비율:소득5천만원주민비율 유의미함.
# 20대 미만 비율:소득6천만원주민비율 유의미함.
# 20대 미만 비율:소득7천만원주민비율 유의미함.
# 20대 미만 비율:소득7천만원이상주민비율 유의미함.
# 20대 미만 비율:총 인구 유의미함.
# 20대 미만 비율:20-30대 비율 유의미함.
# 20대 미만 비율:40-50대 비율 유의미함.
# 20대 미만 비율:60-70대 비율 유의미하지 않음.
# 20대 미만 비율:80대 이상 비율 유의미함.
# 20-30대 비율:가구/인테리어 유의미하지 않음.
# 20-30대 비율:기타 유의미하지 않음.
# 20-30대 비율:도서/음반 유의미하지 않음.
# 20-30대 비율:디지털/가전 유의미하지 않음.
# 20-30대 비율:생활/건강 유의미하지 않음.
# 20-30대 비율:스포츠/레저 유의미하지 않음.
# 20-30대 비율:식품 유의미하지 않음.
# 20-30대 비율:출산/육아 유의미하지 않음.
# 20-30대 비율:패션의류 유의미하지 않음.
# 20-30대 비율:패션잡화 유의미하지 않음.
# 20-30대 비율:화장품/미용 유의미하지 않음.
# 20-30대 비율:총 물량 유의미하지 않음.
# 20-30대 비율:소득2천만원주민비율 유의미하지 않음.
# 20-30대 비율:소득3천만원주민비율 유의미함.
# 20-30대 비율:소득4천만원주민비율 유의미하지 않음.
# 20-30대 비율:소득5천만원주민비율 유의미하지 않음.
# 20-30대 비율:소득6천만원주민비율 유의미하지 않음.
# 20-30대 비율:소득7천만원주민비율 유의미하지 않음.
# 20-30대 비율:소득7천만원이상주민비율 유의미하지 않음.
# 20-30대 비율:총 인구 유의미하지 않음.
# 20-30대 비율:20대 미만 비율 유의미함.
# 20-30대 비율:40-50대 비율 유의미함.
# 20-30대 비율:60-70대 비율 유의미함.
# 20-30대 비율:80대 이상 비율 유의미하지 않음.
# 40-50대 비율:가구/인테리어 유의미하지 않음.
# 40-50대 비율:기타 유의미하지 않음.
# 40-50대 비율:도서/음반 유의미하지 않음.
# 40-50대 비율:디지털/가전 유의미하지 않음.
# 40-50대 비율:생활/건강 유의미하지 않음.
# 40-50대 비율:스포츠/레저 유의미하지 않음.
# 40-50대 비율:식품 유의미하지 않음.
# 40-50대 비율:출산/육아 유의미하지 않음.
# 40-50대 비율:패션의류 유의미하지 않음.
# 40-50대 비율:패션잡화 유의미하지 않음.
# 40-50대 비율:화장품/미용 유의미하지 않음.
# 40-50대 비율:총 물량 유의미하지 않음.
# 40-50대 비율:소득2천만원주민비율 유의미함.
# 40-50대 비율:소득3천만원주민비율 유의미함.
# 40-50대 비율:소득4천만원주민비율 유의미하지 않음.
# 40-50대 비율:소득5천만원주민비율 유의미함.
# 40-50대 비율:소득6천만원주민비율 유의미함.
# 40-50대 비율:소득7천만원주민비율 유의미함.
# 40-50대 비율:소득7천만원이상주민비율 유의미함.
# 40-50대 비율:총 인구 유의미하지 않음.
# 40-50대 비율:20대 미만 비율 유의미함.
# 40-50대 비율:20-30대 비율 유의미함.
# 40-50대 비율:60-70대 비율 유의미하지 않음.
# 40-50대 비율:80대 이상 비율 유의미하지 않음.
# 60-70대 비율:가구/인테리어 유의미함.
# 60-70대 비율:기타 유의미함.
# 60-70대 비율:도서/음반 유의미함.
# 60-70대 비율:디지털/가전 유의미함.
# 60-70대 비율:생활/건강 유의미함.
# 60-70대 비율:스포츠/레저 유의미하지 않음.
# 60-70대 비율:식품 유의미함.
# 60-70대 비율:출산/육아 유의미하지 않음.
# 60-70대 비율:패션의류 유의미하지 않음.
# 60-70대 비율:패션잡화 유의미함.
# 60-70대 비율:화장품/미용 유의미하지 않음.
# 60-70대 비율:총 물량 유의미함.
# 60-70대 비율:소득2천만원주민비율 유의미함.
# 60-70대 비율:소득3천만원주민비율 유의미함.
# 60-70대 비율:소득4천만원주민비율 유의미함.
# 60-70대 비율:소득5천만원주민비율 유의미함.
# 60-70대 비율:소득6천만원주민비율 유의미함.
# 60-70대 비율:소득7천만원주민비율 유의미함.
# 60-70대 비율:소득7천만원이상주민비율 유의미함.
# 60-70대 비율:총 인구 유의미하지 않음.
# 60-70대 비율:20대 미만 비율 유의미하지 않음.
# 60-70대 비율:20-30대 비율 유의미함.
# 60-70대 비율:40-50대 비율 유의미하지 않음.
# 60-70대 비율:80대 이상 비율 유의미함.
# 80대 이상 비율:가구/인테리어 유의미함.
# 80대 이상 비율:기타 유의미함.
# 80대 이상 비율:도서/음반 유의미함.
# 80대 이상 비율:디지털/가전 유의미하지 않음.
# 80대 이상 비율:생활/건강 유의미함.
# 80대 이상 비율:스포츠/레저 유의미함.
# 80대 이상 비율:식품 유의미함.
# 80대 이상 비율:출산/육아 유의미함.
# 80대 이상 비율:패션의류 유의미하지 않음.
# 80대 이상 비율:패션잡화 유의미함.
# 80대 이상 비율:화장품/미용 유의미함.
# 80대 이상 비율:총 물량 유의미함.
# 80대 이상 비율:소득2천만원주민비율 유의미함.
# 80대 이상 비율:소득3천만원주민비율 유의미함.
# 80대 이상 비율:소득4천만원주민비율 유의미하지 않음.
# 80대 이상 비율:소득5천만원주민비율 유의미함.
# 80대 이상 비율:소득6천만원주민비율 유의미함.
# 80대 이상 비율:소득7천만원주민비율 유의미함.
# 80대 이상 비율:소득7천만원이상주민비율 유의미함.
# 80대 이상 비율:총 인구 유의미함.
# 80대 이상 비율:20대 미만 비율 유의미함.
# 80대 이상 비율:20-30대 비율 유의미하지 않음.
# 80대 이상 비율:40-50대 비율 유의미하지 않음.
# 80대 이상 비율:60-70대 비율 유의미함.

# %%
significant_df
# Out:
#         Variable1     Variable2
# 0         가구/인테리어            기타
# 1         가구/인테리어         도서/음반
# 2         가구/인테리어         생활/건강
# 3         가구/인테리어        스포츠/레저
# 4         가구/인테리어            식품
# 5         가구/인테리어         출산/육아
# 6         가구/인테리어          패션의류
# 7         가구/인테리어          패션잡화
# 8         가구/인테리어        화장품/미용
# 9         가구/인테리어          총 물량
# 10        가구/인테리어    소득2천만원주민비율
# 11        가구/인테리어    소득3천만원주민비율
# 12        가구/인테리어    소득5천만원주민비율
# 13        가구/인테리어    소득6천만원주민비율
# 14        가구/인테리어    소득7천만원주민비율
# 15        가구/인테리어  소득7천만원이상주민비율
# 16        가구/인테리어     60-70대 비율
# 17        가구/인테리어     80대 이상 비율
# 18             기타       가구/인테리어
# 19             기타         도서/음반
# 20             기타         생활/건강
# 21             기타        스포츠/레저
# 22             기타            식품
# 23             기타         출산/육아
# 24             기타          패션의류
# 25             기타          패션잡화
# 26             기타        화장품/미용
# 27             기타          총 물량
# 28             기타    소득2천만원주민비율
# 29             기타    소득3천만원주민비율
# 30             기타    소득5천만원주민비율
# 31             기타    소득6천만원주민비율
# 32             기타    소득7천만원주민비율
# 33             기타  소득7천만원이상주민비율
# 34             기타     20대 미만 비율
# 35             기타     60-70대 비율
# 36             기타     80대 이상 비율
# 37          도서/음반       가구/인테리어
# 38          도서/음반            기타
# 39          도서/음반         생활/건강
# 40          도서/음반        스포츠/레저
# 41          도서/음반            식품
# 42          도서/음반         출산/육아
# 43          도서/음반          패션의류
# 44          도서/음반          패션잡화
# 45          도서/음반        화장품/미용
# 46          도서/음반          총 물량
# 47          도서/음반    소득2천만원주민비율
# 48          도서/음반    소득3천만원주민비율
# 49          도서/음반    소득5천만원주민비율
# 50          도서/음반    소득6천만원주민비율
# 51          도서/음반    소득7천만원주민비율
# 52          도서/음반  소득7천만원이상주민비율
# 53          도서/음반     20대 미만 비율
# 54          도서/음반     60-70대 비율
# 55          도서/음반     80대 이상 비율
# 56         디지털/가전          총 물량
# 57         디지털/가전    소득7천만원주민비율
# 58         디지털/가전     60-70대 비율
# 59          생활/건강       가구/인테리어
# 60          생활/건강            기타
# 61          생활/건강         도서/음반
# 62          생활/건강        스포츠/레저
# 63          생활/건강            식품
# 64          생활/건강         출산/육아
# 65          생활/건강          패션의류
# 66          생활/건강          패션잡화
# 67          생활/건강        화장품/미용
# 68          생활/건강          총 물량
# 69          생활/건강    소득2천만원주민비율
# 70          생활/건강    소득3천만원주민비율
# 71          생활/건강    소득5천만원주민비율
# 72          생활/건강    소득6천만원주민비율
# 73          생활/건강    소득7천만원주민비율
# 74          생활/건강  소득7천만원이상주민비율
# 75          생활/건강          총 인구
# 76          생활/건강     20대 미만 비율
# 77          생활/건강     60-70대 비율
# 78          생활/건강     80대 이상 비율
# 79         스포츠/레저       가구/인테리어
# 80         스포츠/레저            기타
# 81         스포츠/레저         도서/음반
# 82         스포츠/레저         생활/건강
# 83         스포츠/레저            식품
# 84         스포츠/레저         출산/육아
# 85         스포츠/레저          패션의류
# 86         스포츠/레저          패션잡화
# 87         스포츠/레저        화장품/미용
# 88         스포츠/레저          총 물량
# 89         스포츠/레저    소득2천만원주민비율
# 90         스포츠/레저    소득5천만원주민비율
# 91         스포츠/레저    소득6천만원주민비율
# 92         스포츠/레저          총 인구
# 93         스포츠/레저     80대 이상 비율
# 94             식품       가구/인테리어
# 95             식품            기타
# 96             식품         도서/음반
# 97             식품         생활/건강
# 98             식품        스포츠/레저
# 99             식품         출산/육아
# 100            식품          패션의류
# 101            식품          패션잡화
# 102            식품        화장품/미용
# 103            식품          총 물량
# 104            식품    소득2천만원주민비율
# 105            식품    소득3천만원주민비율
# 106            식품    소득5천만원주민비율
# 107            식품    소득6천만원주민비율
# 108            식품    소득7천만원주민비율
# 109            식품  소득7천만원이상주민비율
# 110            식품          총 인구
# 111            식품     20대 미만 비율
# 112            식품     60-70대 비율
# 113            식품     80대 이상 비율
# 114         출산/육아       가구/인테리어
# 115         출산/육아            기타
# 116         출산/육아         도서/음반
# 117         출산/육아         생활/건강
# 118         출산/육아        스포츠/레저
# 119         출산/육아            식품
# 120         출산/육아          패션의류
# 121         출산/육아          패션잡화
# 122         출산/육아        화장품/미용
# 123         출산/육아          총 물량
# 124         출산/육아          총 인구
# 125         출산/육아     80대 이상 비율
# 126          패션의류       가구/인테리어
# 127          패션의류            기타
# 128          패션의류         도서/음반
# 129          패션의류         생활/건강
# 130          패션의류        스포츠/레저
# 131          패션의류            식품
# 132          패션의류         출산/육아
# 133          패션의류          패션잡화
# 134          패션의류        화장품/미용
# 135          패션의류          총 물량
# 136          패션의류  소득7천만원이상주민비율
# 137          패션잡화       가구/인테리어
# 138          패션잡화            기타
# 139          패션잡화         도서/음반
# 140          패션잡화         생활/건강
# 141          패션잡화        스포츠/레저
# 142          패션잡화            식품
# 143          패션잡화         출산/육아
# 144          패션잡화          패션의류
# 145          패션잡화        화장품/미용
# 146          패션잡화          총 물량
# 147          패션잡화    소득7천만원주민비율
# 148          패션잡화  소득7천만원이상주민비율
# 149          패션잡화     60-70대 비율
# 150          패션잡화     80대 이상 비율
# 151        화장품/미용       가구/인테리어
# 152        화장품/미용            기타
# 153        화장품/미용         도서/음반
# 154        화장품/미용         생활/건강
# 155        화장품/미용        스포츠/레저
# 156        화장품/미용            식품
# 157        화장품/미용         출산/육아
# 158        화장품/미용          패션의류
# 159        화장품/미용          패션잡화
# 160        화장품/미용          총 물량
# 161        화장품/미용    소득2천만원주민비율
# 162        화장품/미용    소득3천만원주민비율
# 163        화장품/미용    소득5천만원주민비율
# 300          총 인구        스포츠/레저
# 301          총 인구            식품
# 302          총 인구         출산/육아
# 303          총 인구        화장품/미용
# 304          총 인구    소득2천만원주민비율
# 305          총 인구    소득3천만원주민비율
# 306          총 인구    소득4천만원주민비율
# 307          총 인구    소득5천만원주민비율
# 308          총 인구    소득6천만원주민비율
# 309          총 인구     20대 미만 비율
# 310          총 인구     80대 이상 비율
# 311     20대 미만 비율            기타
# 312     20대 미만 비율         도서/음반
# 313     20대 미만 비율         생활/건강
# 314     20대 미만 비율            식품
# 315     20대 미만 비율          총 물량
# 316     20대 미만 비율    소득2천만원주민비율
# 317     20대 미만 비율    소득3천만원주민비율
# 318     20대 미만 비율    소득5천만원주민비율
# 319     20대 미만 비율    소득6천만원주민비율
# 320     20대 미만 비율    소득7천만원주민비율
# 321     20대 미만 비율  소득7천만원이상주민비율
# 322     20대 미만 비율          총 인구
# 323     20대 미만 비율     20-30대 비율
# 324     20대 미만 비율     40-50대 비율
# 325     20대 미만 비율     80대 이상 비율
# 326     20-30대 비율    소득3천만원주민비율
# 327     20-30대 비율     20대 미만 비율
# 328     20-30대 비율     40-50대 비율
# 329     20-30대 비율     60-70대 비율
# 330     40-50대 비율    소득2천만원주민비율
# 331     40-50대 비율    소득3천만원주민비율
# 332     40-50대 비율    소득5천만원주민비율
# 333     40-50대 비율    소득6천만원주민비율
# 334     40-50대 비율    소득7천만원주민비율
# 335     40-50대 비율  소득7천만원이상주민비율
# 336     40-50대 비율     20대 미만 비율
# 337     40-50대 비율     20-30대 비율
# 338     60-70대 비율       가구/인테리어
# 339     60-70대 비율            기타
# 340     60-70대 비율         도서/음반
# 341     60-70대 비율        디지털/가전
# 342     60-70대 비율         생활/건강
# 343     60-70대 비율            식품
# 344     60-70대 비율          패션잡화
# 345     60-70대 비율          총 물량
# 346     60-70대 비율    소득2천만원주민비율
# 347     60-70대 비율    소득3천만원주민비율
# 348     60-70대 비율    소득4천만원주민비율
# 349     60-70대 비율    소득5천만원주민비율
# 350     60-70대 비율    소득6천만원주민비율
# 351     60-70대 비율    소득7천만원주민비율
# 352     60-70대 비율  소득7천만원이상주민비율
# 353     60-70대 비율     20-30대 비율
# 354     60-70대 비율     80대 이상 비율
# 355     80대 이상 비율       가구/인테리어
# 356     80대 이상 비율            기타
# 357     80대 이상 비율         도서/음반
# 358     80대 이상 비율         생활/건강
# 359     80대 이상 비율        스포츠/레저
# 360     80대 이상 비율            식품
# 361     80대 이상 비율         출산/육아
# 362     80대 이상 비율          패션잡화
# 363     80대 이상 비율        화장품/미용
# 364     80대 이상 비율          총 물량
# 365     80대 이상 비율    소득2천만원주민비율
# 366     80대 이상 비율    소득3천만원주민비율
# 367     80대 이상 비율    소득5천만원주민비율
# 368     80대 이상 비율    소득6천만원주민비율
# 369     80대 이상 비율    소득7천만원주민비율
# 370     80대 이상 비율  소득7천만원이상주민비율
# 371     80대 이상 비율          총 인구
# 372     80대 이상 비율     20대 미만 비율
# 373     80대 이상 비율     60-70대 비율

# %% [markdown]
# # 변수간 산점도 시각화 (소득수준 중심으로)

# %% [markdown]
# ## 택배 총 물량과 고소득 수준의 산점도
# - 고소득 수준 지역과 총 물량 사이에는 '양의 상관관계'
# - 고소득의 비율이 높은 수준 지역에서는 상대적으로 많은 택배 물량이 발생하는 경향이 있음.

# %%
# 택배 총 물량, 소득 수준, 지역 이름 선택
data = region_income_ppl[['총 물량', '소득7천만원이상주민비율', '담당지역']]

# 산점도 그리기
plt.figure(figsize=(12, 8))
sns.scatterplot(x='총 물량', y='소득7천만원이상주민비율', data=data)

# 각 데이터 포인트에 지역 이름 주석 추가
for i in range(data.shape[0]):
    plt.annotate(data['담당지역'].iloc[i], (data['총 물량'].iloc[i], data['소득7천만원이상주민비율'].iloc[i]), fontsize=8)

plt.title('택배 총 물량과 고소득 수준의 산점도')
plt.xlabel('택배 총 물량')
plt.ylabel('소득 7천만원 이상 주민 비율')
plt.show()

# %% [markdown]
# ## 택배 총 물량과 저소득 수준의 산점도
# - 저소득 수준 지역과 총 물량 사이에는 '음의 상관관계'
# - 저소득의 비율이 높은 지역에서는 상대적으로 적은 택배 물량이 발생하는 경향이 있음.

# %%
# 택배 총 물량, 소득 수준, 지역 이름 선택
data = region_income_ppl[['총 물량', '소득2천만원주민비율', '담당지역']]

# 산점도 그리기
plt.figure(figsize=(12, 8))
sns.scatterplot(x='총 물량', y='소득2천만원주민비율', data=data)

# 각 데이터 포인트에 지역 이름 주석 추가
for i in range(data.shape[0]):
    plt.annotate(data['담당지역'].iloc[i], (data['총 물량'].iloc[i], data['소득2천만원주민비율'].iloc[i]), fontsize=8)

plt.title('택배 총 물량과 저소득 수준의 산점도')
plt.xlabel('택배 총 물량')
plt.ylabel('소득 2천만원 주민 비율')
plt.show()

# %% [markdown]
# ## 도서/음반 품목과 소득 수준의 산점도
# - 이전 히트맵에서 상대적으로 고소득 비율이 높은 지역에서 도서/음반과의 '양의 상관관계'가 강하게 나옴.
# - 소득 5천만원주민비율을 기점으로 음에서 양의 상관관계를 바뀜.

# %%
# 선택할 품목
selected_item = '도서/음반'

# 선택할 소득 수준 변수
income_levels = ['소득2천만원주민비율', '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율', '소득6천만원주민비율', '소득7천만원주민비율', '소득7천만원이상주민비율']

# 서브플롯 생성
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

# 소득 수준별로 산점도 그리기
for i, income_level in enumerate(income_levels):
    row, col = divmod(i, 4)  # 서브플롯 위치 계산
    ax = axes[row, col]

    sns.scatterplot(x=selected_item, y=income_level, data=region_income_ppl, ax=ax)
    ax.set_title(f'{selected_item} vs {income_level}')
    ax.set_xlabel(selected_item)
    ax.set_ylabel(income_level)

# 서브플롯트 간의 간격 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 가구/인테리어 품목과 소득 수준의 산점도
# - 소득 5천만원주민비율을 기점으로 관계없음에서 양의 상관관계를 바뀜.

# %%
# 선택할 품목
selected_item = '가구/인테리어'

# 선택할 소득 수준 변수
income_levels = ['소득2천만원주민비율', '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율', '소득6천만원주민비율', '소득7천만원주민비율', '소득7천만원이상주민비율']

# 서브플롯 생성
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

# 소득 수준별로 산점도 그리기
for i, income_level in enumerate(income_levels):
    row, col = divmod(i, 4)  # 서브플롯 위치 계산
    ax = axes[row, col]

    sns.scatterplot(x=selected_item, y=income_level, data=region_income_ppl, ax=ax)
    ax.set_title(f'{selected_item} vs {income_level}')
    ax.set_xlabel(selected_item)
    ax.set_ylabel(income_level)

# 서브플롯트 간의 간격 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 생활/건강 품목과 소득 수준의 산점도
# - 소득 5천만원주민비율을 기점으로 관계 없음에서 양의 상관관계를 바뀜.

# %%
# 선택할 품목
selected_item = '생활/건강'

# 선택할 소득 수준 변수
income_levels = ['소득2천만원주민비율', '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율', '소득6천만원주민비율', '소득7천만원주민비율', '소득7천만원이상주민비율']

# 서브플롯 생성
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

# 소득 수준별로 산점도 그리기
for i, income_level in enumerate(income_levels):
    row, col = divmod(i, 4)  # 서브플롯 위치 계산
    ax = axes[row, col]

    sns.scatterplot(x=selected_item, y=income_level, data=region_income_ppl, ax=ax)
    ax.set_title(f'{selected_item} vs {income_level}')
    ax.set_xlabel(selected_item)
    ax.set_ylabel(income_level)

# 서브플롯트 간의 간격 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 식품 품목과 소득 수준의 산점도
# - 소득 5천만원주민비율을 기점으로 관계 없음에서 양의 상관관계를 바뀜.

# %%
# 선택할 품목
selected_item = '식품'

# 선택할 소득 수준 변수
income_levels = ['소득2천만원주민비율', '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율', '소득6천만원주민비율', '소득7천만원주민비율', '소득7천만원이상주민비율']

# 서브플롯 생성
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

# 소득 수준별로 산점도 그리기
for i, income_level in enumerate(income_levels):
    row, col = divmod(i, 4)  # 서브플롯 위치 계산
    ax = axes[row, col]

    sns.scatterplot(x=selected_item, y=income_level, data=region_income_ppl, ax=ax)
    ax.set_title(f'{selected_item} vs {income_level}')
    ax.set_xlabel(selected_item)
    ax.set_ylabel(income_level)

# 서브플롯트 간의 간격 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 품목별 택배 총물량 - 소득수준 중심 산점도 모아보기

# %%
# 관심 있는 특성과 소득 수준별 컬럼 선택
features = ['가구/인테리어', '도서/음반', '생활/건강', '식품']
income_columns = ["소득2천만원주민비율", "소득3천만원주민비율", "소득4천만원주민비율", "소득5천만원주민비율", "소득6천만원주민비율", "소득7천만원주민비율", "소득7천만원이상주민비율"]

# 서브플롯을 사용한 산점도 그리기
fig, axes = plt.subplots(nrows=len(income_columns), ncols=len(features), figsize=(15, 12))
for i, income_column in enumerate(income_columns):
    for j, feature in enumerate(features):
        ax = axes[i, j]
        sns.scatterplot(x=feature, y=income_column, data=region_income_ppl, ax=ax)
        ax.set_xlabel(feature)
        ax.set_ylabel(income_column)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 변수간 산점도 시각화 (인구 중심으로)

# %% [markdown]
# ## 택배 총 물량과 총 인구의 산점도
# - 총 인구와 총 물량 사이에는 양의 상관관계
# - 한 지역의 인구가 많을 때 많은 택배 물량이 발생할 경향이 있음.

# %%
data = region_income_ppl[['총 물량', '총 인구', '담당지역']]

# 산점도 그리기
plt.figure(figsize=(12, 8))
sns.scatterplot(x='총 물량', y='총 인구', data=data)

# 각 데이터 포인트에 지역 이름 주석 추가
for i in range(data.shape[0]):
    plt.annotate(data['담당지역'].iloc[i], (data['총 물량'].iloc[i], data['총 인구'].iloc[i]), fontsize=8)

plt.title('택배 총 물량과 총 인구의 산점도')
plt.xlabel('택배 총 물량')
plt.ylabel('총 인구')
plt.show()

# %%
region_income_ppl.columns
# Out:
# Index(['담당지역', '터미널이름', '가구/인테리어', '기타', '도서/음반', '디지털/가전', '생활/건강', '스포츠/레저',
#        '식품', '출산/육아', '패션의류', '패션잡화', '화장품/미용', '총 물량', '소득2천만원주민비율',
#        '소득3천만원주민비율', '소득4천만원주민비율', '소득5천만원주민비율', '소득6천만원주민비율', '소득7천만원주민비율',
#        '소득7천만원이상주민비율', '총 인구', '20대 미만 비율', '20-30대 비율', '40-50대 비율',
#        '60-70대 비율', '80대 이상 비율'],
#       dtype='object')

# %% [markdown]
# ## 택배 총 물량과 연령대별 산점도
# - 보통 20대 미만부터 40~50대 비율이 높은 지역과 총 물량은 양의 상관관계
# - 60~70대, 80대 이상 비율이 높은 지역과 총 물량은 음의 상관관계를 가진다.
# - 가설검정일 때 연령대와 관련된 변수로부터 생성된 상관관계가 유의미하지 않은 경우가 다소 있음.
# - 소득수준만큼 확실하게 말할 수는 없지만, 고령화된 지역일수록 택배 총 물량이 적어진다고 판단.

# %%
age_columns = ['20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']

# 산점도 그리기
fig, axes = plt.subplots(nrows=1, ncols=len(age_columns), figsize=(15, 5))
for i, age_column in enumerate(age_columns):
    ax = axes[i]
    sns.scatterplot(x='총 물량', y=age_column, data=region_income_ppl, ax=ax)
    ax.set_xlabel('총 물량')
    ax.set_ylabel(age_column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 품목별 택배 총 물량 - 연령대 중심 산점도 모아보기

# %%
# 관심 있는 특성과 소득 수준별 컬럼 선택
features = ['가구/인테리어', '도서/음반', '생활/건강', '식품']
age_columns = ['20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']

# 서브플롯을 사용한 산점도 그리기
fig, axes = plt.subplots(nrows=len(age_columns), ncols=len(features), figsize=(15, 12))
for i, age_columns in enumerate(age_columns):
    for j, feature in enumerate(features):
        ax = axes[i, j]
        sns.scatterplot(x=feature, y=age_columns, data=region_income_ppl, ax=ax)
        ax.set_xlabel(feature)
        ax.set_ylabel(age_columns)

plt.tight_layout()
plt.show()
