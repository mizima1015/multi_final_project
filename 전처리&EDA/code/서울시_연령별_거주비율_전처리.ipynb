# %% [markdown]
# # 데이터 준비

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/final'
people_2122 = pd.read_csv(DATA_PATH + '/서울시 주민등록인구(연령별_동별)_2021-2022년.csv')

# %% [markdown]
# # 2021-2022년

# %%
people_2122.head()
# Out:
#    동별(1)  동별(2)   항목     2021  2021.1  2021.2  2021.3  2021.4  2021.5  2021.6  \
# 0  동별(1)  동별(2)   항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세
# 1     합계     소계    계  9736027  250044  345196  372040  394566  638174  847622
# 2     합계     소계  한국인  9509458  244538  339145  367879  388257  603077  819200
# 3     합계     소계  외국인   226569    5506    6051    4161    6309   35097   28422
# 4    종로구     소계    계   153789    2849    4439    5092    5849   12935   14201
#
#    ... 2022.12 2022.13 2022.14 2022.15 2022.16 2022.17 2022.18 2022.19  \
# 0  ...  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세  85~89세  90~94세
# 1  ...  713186  729540  585417  410611  305700  219981  101884   34635
# 2  ...  690974  717931  579856  408481  305015  219561  101648   34536
# 3  ...   22212   11609    5561    2130     685     420     236      99
# 4  ...   11928   11688    9047    6251    5237    4358    2117     729
#
#   2022.20  2022.21
# 0  95~99세  100세 이상
# 1    7864     1319
# ...

# %% [markdown]
# ## 2021년

# %%
people_2021 = people_2122.iloc[:, :25]

# %%
people_2021.head()
# Out:
#    동별(1)  동별(2)   항목     2021  2021.1  2021.2  2021.3  2021.4  2021.5  2021.6  \
# 0  동별(1)  동별(2)   항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세
# 1     합계     소계    계  9736027  250044  345196  372040  394566  638174  847622
# 2     합계     소계  한국인  9509458  244538  339145  367879  388257  603077  819200
# 3     합계     소계  외국인   226569    5506    6051    4161    6309   35097   28422
# 4    종로구     소계    계   153789    2849    4439    5092    5849   12935   14201
#
#    ... 2021.12 2021.13 2021.14 2021.15 2021.16 2021.17 2021.18 2021.19  \
# 0  ...  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세  85~89세  90~94세
# 1  ...  730761  732970  568036  398337  299887  199533   96094   33907
# 2  ...  705302  722662  563260  396569  299231  199138   95871   33815
# 3  ...   25459   10308    4776    1768     656     395     223      92
# 4  ...   12371   11770    8954    6312    5400    4089    2078     753
#
#   2021.20  2021.21
# 0  95~99세  100세 이상
# 1    7957     1665
# ...

# %%
people_2021 = people_2021.rename(columns=people_2021.iloc[0]).drop(people_2021.index[0]).reset_index(drop=True)
people_2021.head()
# Out:
#   동별(1) 동별(2)   항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세  \
# 0    합계    소계    계  9736027  250044  345196  372040  394566  638174  847622
# 1    합계    소계  한국인  9509458  244538  339145  367879  388257  603077  819200
# 2    합계    소계  외국인   226569    5506    6051    4161    6309   35097   28422
# 3   종로구    소계    계   153789    2849    4439    5092    5849   12935   14201
# 4   종로구    소계  한국인   144683    2720    4264    4934    5447    9965   12837
#
#    ...  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세 85~89세 90~94세 95~99세  \
# 0  ...  730761  732970  568036  398337  299887  199533  96094  33907   7957
# 1  ...  705302  722662  563260  396569  299231  199138  95871  33815   7920
# 2  ...   25459   10308    4776    1768     656     395    223     92     37
# 3  ...   12371   11770    8954    6312    5400    4089   2078    753    200
# 4  ...   11857   11511    8841    6254    5383    4078   2071    750    200
#
#   100세 이상
# 0    1665
# 1    1643
# 2      22
# ...

# %%
people_2021 = people_2021.drop(people_2021.index[:3])
people_2021.head()
# Out:
#   동별(1) 동별(2)   항목      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세  ...  \
# 3   종로구    소계    계  153789  2849  4439   5092   5849  12935  14201  ...
# 4   종로구    소계  한국인  144683  2720  4264   4934   5447   9965  12837  ...
# 5   종로구    소계  외국인    9106   129   175    158    402   2970   1364  ...
# 6   종로구   사직동    계    9636   207   362    346    336    473    753  ...
# 7   종로구   사직동  한국인    9372   202   356    342    333    465    737  ...
#
#   55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 3  12371  11770   8954   6312   5400   4089   2078    753    200      32
# 4  11857  11511   8841   6254   5383   4078   2071    750    200      32
# 5    514    259    113     58     17     11      7      3      -       -
# 6    726    724    505    361    343    311    168     63     22       1
# 7    705    714    493    357    343    309    167     62     22       1
#
# [5 rows x 25 columns]

# %%
people_2021 = people_2021[~people_2021['동별(2)'].str.contains('동')]
people_2021 = people_2021[~people_2021['항목'].str.contains('인')]
people_2021.head()
# Out:
#     동별(1) 동별(2) 항목      합계  0~4세   5~9세 10~14세 15~19세 20~24세 25~29세  ...  \
# 3     종로구    소계  계  153789  2849   4439   5092   5849  12935  14201  ...
# 57     중구    소계  계  131787  3140   3674   3272   3698   9114  12329  ...
# 105   용산구    소계  계  237285  6364   7664   7601   8218  14147  20868  ...
# 108   성동구    소계  계  292672  9305  10155   9065  10109  20309  26065  ...
# 111   광진구    소계  계  352627  7661  10714  12070  13318  28026  38693  ...
#
#     55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 3    12371  11770   8954   6312   5400   4089   2078    753    200      32
# 57   10382  10406   8205   5709   4634   3308   1693    670    147      26
# 105  17652  17147  12772   8916   7255   5632   2997   1143    282      73
# 108  22491  22099  15988  11193   8973   6080   2933    965    197      51
# 111  26680  25910  18905  12517   9487   6515   3000   1004    244      51
#
# [5 rows x 25 columns]

# %%
people_2021 = people_2021.drop(['동별(2)', '항목'], axis = 1)
columns = {'동별(1)' : '지역'}
people_2021 = people_2021.rename(columns = columns)
people_2021
# Out:
#        지역      합계   0~4세   5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  \
# 3     종로구  153789   2849   4439   5092   5849  12935  14201  11044   9838
# 57     중구  131787   3140   3674   3272   3698   9114  12329  11352  10386
# 105   용산구  237285   6364   7664   7601   8218  14147  20868  21403  19988
# 108   성동구  292672   9305  10155   9065  10109  20309  26065  23908  24086
# 111   광진구  352627   7661  10714  12070  13318  28026  38693  30680  26130
# 114  동대문구  352006   8854  11049  10993  12527  31718  33747  25993  24943
# 117   중랑구  391885   9601  12009  12142  13487  22512  32697  30159  28061
# 120   성북구  440142  11424  16190  17352  19360  34899  35927  29603  30406
# 123   강북구  302563   5776   8522   9757  11145  19022  23046  19094  18808
# 126   도봉구  319373   6936  10188  11469  12905  19471  22626  19619  20154
# 129   노원구  514946  12189  18577  23497  27049  36784  35017  31209  32744
# 132   은평구  477173  11636  16199  17699  19707  28498  37537  33948  34078
# ...

# %%
people_2021 = people_2021.reset_index(drop = True)
people_2021.head()
# Out:
#     지역      합계  0~4세   5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  ...  \
# 0  종로구  153789  2849   4439   5092   5849  12935  14201  11044   9838  ...
# 1   중구  131787  3140   3674   3272   3698   9114  12329  11352  10386  ...
# 2  용산구  237285  6364   7664   7601   8218  14147  20868  21403  19988  ...
# 3  성동구  292672  9305  10155   9065  10109  20309  26065  23908  24086  ...
# 4  광진구  352627  7661  10714  12070  13318  28026  38693  30680  26130  ...
#
#   55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 0  12371  11770   8954   6312   5400   4089   2078    753    200      32
# 1  10382  10406   8205   5709   4634   3308   1693    670    147      26
# 2  17652  17147  12772   8916   7255   5632   2997   1143    282      73
# 3  22491  22099  15988  11193   8973   6080   2933    965    197      51
# 4  26680  25910  18905  12517   9487   6515   3000   1004    244      51
#
# [5 rows x 23 columns]

# %%
people_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     object
#  2   0~4세     25 non-null     object
#  3   5~9세     25 non-null     object
#  4   10~14세   25 non-null     object
#  5   15~19세   25 non-null     object
#  6   20~24세   25 non-null     object
#  7   25~29세   25 non-null     object
#  8   30~34세   25 non-null     object
#  9   35~39세   25 non-null     object
#  10  40~44세   25 non-null     object
#  11  45~49세   25 non-null     object
#  12  50~54세   25 non-null     object
#  13  55~59세   25 non-null     object
#  14  60~64세   25 non-null     object
#  15  65~69세   25 non-null     object
#  16  70~74세   25 non-null     object
#  17  75~79세   25 non-null     object
#  18  80~84세   25 non-null     object
#  19  85~89세   25 non-null     object
# ...

# %%
for column in ['합계', '0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세',
               '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상']:
    people_2021[column] = pd.to_numeric(people_2021[column], errors='coerce')

people_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     int64
#  2   0~4세     25 non-null     int64
#  3   5~9세     25 non-null     int64
#  4   10~14세   25 non-null     int64
#  5   15~19세   25 non-null     int64
#  6   20~24세   25 non-null     int64
#  7   25~29세   25 non-null     int64
#  8   30~34세   25 non-null     int64
#  9   35~39세   25 non-null     int64
#  10  40~44세   25 non-null     int64
#  11  45~49세   25 non-null     int64
#  12  50~54세   25 non-null     int64
#  13  55~59세   25 non-null     int64
#  14  60~64세   25 non-null     int64
#  15  65~69세   25 non-null     int64
#  16  70~74세   25 non-null     int64
#  17  75~79세   25 non-null     int64
#  18  80~84세   25 non-null     int64
#  19  85~89세   25 non-null     int64
#  20  90~94세   25 non-null     int64
# ...

# %%
people_2021['20대 미만'] = people_2021['0~4세'] +	people_2021['5~9세'] + people_2021['10~14세'] +	people_2021['15~19세']
people_2021['20-30대'] = people_2021['20~24세'] +	people_2021['25~29세'] + people_2021['30~34세'] +	people_2021['35~39세']
people_2021['40-50대'] = people_2021['40~44세'] +	people_2021['45~49세'] + people_2021['50~54세'] +	people_2021['55~59세']
people_2021['60-70대'] = people_2021['60~64세'] +	people_2021['65~69세'] + people_2021['70~74세'] +	people_2021['75~79세']
people_2021['80대 이상'] = people_2021['80~84세'] +	people_2021['85~89세'] + people_2021['90~94세'] +	people_2021['95~99세'] + people_2021['100세 이상']
people_age_2021 = people_2021.drop(['0~4세',	'5~9세', '10~14세',	'15~19세', '20~24세',	'25~29세', '30~34세',	'35~39세', '40~44세',	'45~49세', '50~54세',
                                '55~59세', '60~64세',	'65~69세', '70~74세',	'75~79세', '80~84세',	'85~89세', '90~94세',	'95~99세', '100세 이상'], axis = 1)
people_age_2021.head()
# Out:
#     지역      합계  20대 미만  20-30대  40-50대  60-70대  80대 이상
# 0  종로구  153789   18229   48018   47954   32436    7152
# 1   중구  131787   13784   43181   40024   28954    5844
# 2  용산구  237285   29847   76406   74815   46090   10127
# 3  성동구  292672   38634   94368   91191   58253   10226
# 4  광진구  352627   43763  123529  107702   66819   10814

# %%
people_age_2021['20대 미만 비율'] = people_age_2021['20대 미만'] / people_age_2021['합계'] * 100
people_age_2021['20-30대 비율'] = people_age_2021['20-30대'] / people_age_2021['합계'] * 100
people_age_2021['40-50대 비율'] = people_age_2021['40-50대'] / people_age_2021['합계'] * 100
people_age_2021['60-70대 비율'] = people_age_2021['60-70대'] / people_age_2021['합계'] * 100
people_age_2021['80대 이상 비율'] = people_age_2021['80대 이상'] / people_age_2021['합계'] * 100

people_agerate_2021 = people_age_2021[['지역', '합계', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']]
people_agerate_2021['20대 미만 비율'] = people_agerate_2021['20대 미만 비율'].round(2)
people_agerate_2021['20-30대 비율'] = people_agerate_2021['20-30대 비율'].round(2)
people_agerate_2021['40-50대 비율'] = people_agerate_2021['40-50대 비율'].round(2)
people_agerate_2021['60-70대 비율'] = people_agerate_2021['60-70대 비율'].round(2)
people_agerate_2021['80대 이상 비율'] = people_agerate_2021['80대 이상 비율'].round(2)
people_agerate_2021.head()
# Out:
# <ipython-input-15-061dc81731a8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2021['20대 미만 비율'] = people_agerate_2021['20대 미만 비율'].round(2)
# <ipython-input-15-061dc81731a8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2021['20-30대 비율'] = people_agerate_2021['20-30대 비율'].round(2)
# <ipython-input-15-061dc81731a8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## 2022년

# %%
people_2022 = people_2122.iloc[:, list(range(3)) + list(range(25, len(people_2122.columns)))]

# %%
people_2022.head()
# Out:
#    동별(1)  동별(2)   항목     2022  2022.1  2022.2  2022.3  2022.4  2022.5  2022.6  \
# 0  동별(1)  동별(2)   항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세
# 1     합계     소계    계  9667669  232724  323365  366579  394995  621697  844569
# 2     합계     소계  한국인  9428372  227619  317698  362502  386616  578374  811109
# 3     합계     소계  외국인   239297    5105    5667    4077    8379   43323   33460
# 4    종로구     소계    계   152211    2694    4100    4930    5948   13088   14547
#
#    ... 2022.12 2022.13 2022.14 2022.15 2022.16 2022.17 2022.18 2022.19  \
# 0  ...  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세  85~89세  90~94세
# 1  ...  713186  729540  585417  410611  305700  219981  101884   34635
# 2  ...  690974  717931  579856  408481  305015  219561  101648   34536
# 3  ...   22212   11609    5561    2130     685     420     236      99
# 4  ...   11928   11688    9047    6251    5237    4358    2117     729
#
#   2022.20  2022.21
# 0  95~99세  100세 이상
# 1    7864     1319
# ...

# %%
people_2022 = people_2022.rename(columns=people_2022.iloc[0]).drop(people_2022.index[0]).reset_index(drop=True)
people_2022.head()
# Out:
#   동별(1) 동별(2)   항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세  \
# 0    합계    소계    계  9667669  232724  323365  366579  394995  621697  844569
# 1    합계    소계  한국인  9428372  227619  317698  362502  386616  578374  811109
# 2    합계    소계  외국인   239297    5105    5667    4077    8379   43323   33460
# 3   종로구    소계    계   152211    2694    4100    4930    5948   13088   14547
# 4   종로구    소계  한국인   141379    2512    3891    4718    5369    9563   12721
#
#    ...  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세  85~89세 90~94세 95~99세  \
# 0  ...  713186  729540  585417  410611  305700  219981  101884  34635   7864
# 1  ...  690974  717931  579856  408481  305015  219561  101648  34536   7818
# 2  ...   22212   11609    5561    2130     685     420     236     99     46
# 3  ...   11928   11688    9047    6251    5237    4358    2117    729    190
# 4  ...   11471   11399    8902    6184    5220    4345    2109    725    190
#
#   100세 이상
# 0    1319
# 1    1292
# 2      27
# ...

# %%
people_2022 = people_2022.drop(people_2022.index[:3])
people_2022 = people_2022[~people_2022['동별(2)'].str.contains('동')]
people_2022 = people_2022[~people_2022['항목'].str.contains('인')]
people_2022.head()
# Out:
#     동별(1) 동별(2) 항목      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세  ...  \
# 3     종로구    소계  계  152211  2694  4100   4930   5948  13088  14547  ...
# 57     중구    소계  계  130785  3011  3454   3166   3785   9047  12365  ...
# 105   용산구    소계  계  233284  6019  7252   7421   8056  13547  20648  ...
# 108   성동구    소계  계  288234  8752  9695   8739  10155  19876  25669  ...
# 111   광진구    소계  계  351252  7052  9992  11717  13653  27763  38607  ...
#
#     55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 3    11928  11688   9047   6251   5237   4358   2117    729    190      29
# 57   10023  10251   8401   5809   4587   3617   1784    670    157      30
# 105  17050  16847  13093   8778   6935   5776   3080   1097    237      41
# 108  21574  22008  16592  11217   8920   6642   3132    966    201      50
# 111  26158  25876  19565  13086   9725   7125   3223   1051    252      44
#
# [5 rows x 25 columns]

# %%
people_2022 = people_2022.drop(['동별(2)', '항목'], axis = 1)
columns = {'동별(1)' : '지역'}
people_2022 = people_2022.rename(columns = columns)
people_2022.head()
# Out:
#       지역      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  ...  \
# 3    종로구  152211  2694  4100   4930   5948  13088  14547  11419   9553  ...
# 57    중구  130785  3011  3454   3166   3785   9047  12365  11790  10046  ...
# 105  용산구  233284  6019  7252   7421   8056  13547  20648  22474  19168  ...
# 108  성동구  288234  8752  9695   8739  10155  19876  25669  24053  22830  ...
# 111  광진구  351252  7052  9992  11717  13653  27763  38607  31972  24930  ...
#
#     55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 3    11928  11688   9047   6251   5237   4358   2117    729    190      29
# 57   10023  10251   8401   5809   4587   3617   1784    670    157      30
# 105  17050  16847  13093   8778   6935   5776   3080   1097    237      41
# 108  21574  22008  16592  11217   8920   6642   3132    966    201      50
# 111  26158  25876  19565  13086   9725   7125   3223   1051    252      44
#
# [5 rows x 23 columns]

# %%
people_2022 = people_2022.reset_index(drop = True)
people_2022.head()
# Out:
#     지역      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  ...  \
# 0  종로구  152211  2694  4100   4930   5948  13088  14547  11419   9553  ...
# 1   중구  130785  3011  3454   3166   3785   9047  12365  11790  10046  ...
# 2  용산구  233284  6019  7252   7421   8056  13547  20648  22474  19168  ...
# 3  성동구  288234  8752  9695   8739  10155  19876  25669  24053  22830  ...
# 4  광진구  351252  7052  9992  11717  13653  27763  38607  31972  24930  ...
#
#   55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 0  11928  11688   9047   6251   5237   4358   2117    729    190      29
# 1  10023  10251   8401   5809   4587   3617   1784    670    157      30
# 2  17050  16847  13093   8778   6935   5776   3080   1097    237      41
# 3  21574  22008  16592  11217   8920   6642   3132    966    201      50
# 4  26158  25876  19565  13086   9725   7125   3223   1051    252      44
#
# [5 rows x 23 columns]

# %%
for column in ['합계', '0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세',
               '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상']:
    people_2022[column] = pd.to_numeric(people_2022[column], errors='coerce')

people_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     int64
#  2   0~4세     25 non-null     int64
#  3   5~9세     25 non-null     int64
#  4   10~14세   25 non-null     int64
#  5   15~19세   25 non-null     int64
#  6   20~24세   25 non-null     int64
#  7   25~29세   25 non-null     int64
#  8   30~34세   25 non-null     int64
#  9   35~39세   25 non-null     int64
#  10  40~44세   25 non-null     int64
#  11  45~49세   25 non-null     int64
#  12  50~54세   25 non-null     int64
#  13  55~59세   25 non-null     int64
#  14  60~64세   25 non-null     int64
#  15  65~69세   25 non-null     int64
#  16  70~74세   25 non-null     int64
#  17  75~79세   25 non-null     int64
#  18  80~84세   25 non-null     int64
#  19  85~89세   25 non-null     int64
#  20  90~94세   25 non-null     int64
# ...

# %%
people_2022['20대 미만'] = people_2022['0~4세'] +	people_2022['5~9세'] + people_2022['10~14세'] +	people_2022['15~19세']
people_2022['20-30대'] = people_2022['20~24세'] +	people_2022['25~29세'] + people_2022['30~34세'] +	people_2022['35~39세']
people_2022['40-50대'] = people_2022['40~44세'] +	people_2022['45~49세'] + people_2022['50~54세'] +	people_2022['55~59세']
people_2022['60-70대'] = people_2022['60~64세'] +	people_2022['65~69세'] + people_2022['70~74세'] +	people_2022['75~79세']
people_2022['80대 이상'] = people_2022['80~84세'] +	people_2022['85~89세'] + people_2022['90~94세'] +	people_2022['95~99세'] + people_2022['100세 이상']
people_age_2022 = people_2022.drop(['0~4세',	'5~9세', '10~14세',	'15~19세', '20~24세',	'25~29세', '30~34세',	'35~39세', '40~44세',	'45~49세', '50~54세',
                                '55~59세', '60~64세',	'65~69세', '70~74세',	'75~79세', '80~84세',	'85~89세', '90~94세',	'95~99세', '100세 이상'], axis = 1)
people_age_2022.head()
# Out:
#     지역      합계  20대 미만  20-30대  40-50대  60-70대  80대 이상
# 0  종로구  152211   17672   48607   46286   32223    7423
# 1   중구  130785   13416   43248   38815   29048    6258
# 2  용산구  233284   28748   75837   72815   45653   10231
# 3  성동구  288234   37341   92428   88737   58737   10991
# 4  광진구  351252   42414  123272  105619   68252   11695

# %%
people_age_2022['20대 미만 비율'] = people_age_2022['20대 미만'] / people_age_2022['합계'] * 100
people_age_2022['20-30대 비율'] = people_age_2022['20-30대'] / people_age_2022['합계'] * 100
people_age_2022['40-50대 비율'] = people_age_2022['40-50대'] / people_age_2022['합계'] * 100
people_age_2022['60-70대 비율'] = people_age_2022['60-70대'] / people_age_2022['합계'] * 100
people_age_2022['80대 이상 비율'] = people_age_2022['80대 이상'] / people_age_2022['합계'] * 100

people_agerate_2022 = people_age_2022[['지역', '합계', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']]
people_agerate_2022['20대 미만 비율'] = people_agerate_2022['20대 미만 비율'].round(2)
people_agerate_2022['20-30대 비율'] = people_agerate_2022['20-30대 비율'].round(2)
people_agerate_2022['40-50대 비율'] = people_agerate_2022['40-50대 비율'].round(2)
people_agerate_2022['60-70대 비율'] = people_agerate_2022['60-70대 비율'].round(2)
people_agerate_2022['80대 이상 비율'] = people_agerate_2022['80대 이상 비율'].round(2)
people_agerate_2022.head()
# Out:
# <ipython-input-24-de976385323b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2022['20대 미만 비율'] = people_agerate_2022['20대 미만 비율'].round(2)
# <ipython-input-24-de976385323b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2022['20-30대 비율'] = people_agerate_2022['20-30대 비율'].round(2)
# <ipython-input-24-de976385323b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # 2023년

# %%
people_2023 = pd.read_csv(DATA_PATH + '/서울시 주민등록인구(연령별_동별)_2023-1분기~3분기.csv')
people_2023.head()
# Out:
#    동별(1)  동별(2)   항목 2023 1/4 2023 1/4.1 2023 1/4.2 2023 1/4.3 2023 1/4.4  \
# 0  동별(1)  동별(2)   항목       합계       0~4세       5~9세     10~14세     15~19세
# 1     합계     소계    계  9668008     227792     318362     364760     393817
# 2     합계     소계  한국인  9426404     223600     312530     360436     388258
# 3     합계     소계  외국인   241604       4192       5832       4324       5559
# 4    종로구     소계    계   152212       2599       3960       4908       5827
#
#   2023 1/4.5 2023 1/4.6  ... 2023 3/4.12 2023 3/4.13 2023 3/4.14 2023 3/4.15  \
# 0     20~24세     25~29세  ...      55~59세      60~64세      65~69세      70~74세
# 1     615813     845503  ...      714371      730420      606658      417635
# 2     575672     807658  ...      693973      716791      600380      415201
# 3      40141      37845  ...       20398       13629        6278        2434
# 4      12901      14886  ...       11837       11768        9375        6277
#
# ...

# %% [markdown]
# ## 2023년 1분기

# %%
people_2023_1 = people_2023.iloc[:, :25]
people_2023_1.head()
# Out:
#    동별(1)  동별(2)   항목 2023 1/4 2023 1/4.1 2023 1/4.2 2023 1/4.3 2023 1/4.4  \
# 0  동별(1)  동별(2)   항목       합계       0~4세       5~9세     10~14세     15~19세
# 1     합계     소계    계  9668008     227792     318362     364760     393817
# 2     합계     소계  한국인  9426404     223600     312530     360436     388258
# 3     합계     소계  외국인   241604       4192       5832       4324       5559
# 4    종로구     소계    계   152212       2599       3960       4908       5827
#
#   2023 1/4.5 2023 1/4.6  ... 2023 1/4.12 2023 1/4.13 2023 1/4.14 2023 1/4.15  \
# 0     20~24세     25~29세  ...      55~59세      60~64세      65~69세      70~74세
# 1     615813     845503  ...      712102      733800      593745      413268
# 2     575672     807658  ...      691598      718898      587233      410711
# 3      40141      37845  ...       20504       14902        6512        2557
# 4      12901      14886  ...       11917       11809        9143        6285
#
# ...

# %%
people_2023_1 = people_2023_1.rename(columns=people_2023_1.iloc[0]).drop(people_2023_1.index[0]).reset_index(drop=True)
people_2023_1 = people_2023_1.drop(people_2023_1.index[:3])
people_2023_1 = people_2023_1[~people_2023_1['동별(2)'].str.contains('동')]
people_2023_1 = people_2023_1[~people_2023_1['항목'].str.contains('인')]
people_2023_1
# Out:
#     동별(1) 동별(2) 항목      합계   0~4세   5~9세 10~14세 15~19세 20~24세 25~29세  ...  \
# 3     종로구    소계  계  152212   2599   3960   4908   5827  12901  14886  ...
# 57     중구    소계  계  131390   2950   3363   3167   3742   8701  12703  ...
# 105   용산구    소계  계  232482   5784   7102   7382   8069  13278  20398  ...
# 108   성동구    소계  계  287240   8482   9486   8680  10237  19523  25633  ...
# 111   광진구    소계  계  350925   6863   9815  11594  13466  27432  38876  ...
# 114  동대문구    소계  계  354884   8162  10502  10892  12735  32456  35726  ...
# 117   중랑구    소계  계  389928   9149  11264  11875  13072  20963  31926  ...
# 120   성북구    소계  계  441855  10562  15113  16963  19968  36244  36289  ...
# 123   강북구    소계  계  296934   5059   7652   9279  10793  18446  22627  ...
# 126   도봉구    소계  계  312858   6043   9179  10947  12373  17768  21817  ...
# 129   노원구    소계  계  506989  11092  16736  22156  27095  35563  34168  ...
# 132   은평구    소계  계  468766  10620  14653  17083  19175  26553  36748  ...
# ...

# %%
people_2023_1 = people_2023_1.drop(['동별(2)', '항목'], axis = 1)
columns = {'동별(1)' : '지역'}
people_2023_1 = people_2023_1.rename(columns = columns)
people_2023_1 = people_2023_1.reset_index(drop = True)
people_2023_1.head()
# Out:
#     지역      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  ...  \
# 0  종로구  152212  2599  3960   4908   5827  12901  14886  11600   9414  ...
# 1   중구  131390  2950  3363   3167   3742   8701  12703  12060  10060  ...
# 2  용산구  232482  5784  7102   7382   8069  13278  20398  22428  18991  ...
# 3  성동구  287240  8482  9486   8680  10237  19523  25633  24005  22552  ...
# 4  광진구  350925  6863  9815  11594  13466  27432  38876  32258  24721  ...
#
#   55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 0  11917  11809   9143   6285   5271   4404   2196    748    184      34
# 1   9993  10360   8538   5841   4591   3693   1811    687    163      29
# 2  17139  16988  13330   8805   6939   5790   3197   1120    245      52
# 3  21634  22018  16791  11271   8928   6746   3234   1002    216      50
# 4  26074  26148  19868  13157   9828   7282   3368   1052    256      43
#
# [5 rows x 23 columns]

# %%
people_2023_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     object
#  2   0~4세     25 non-null     object
#  3   5~9세     25 non-null     object
#  4   10~14세   25 non-null     object
#  5   15~19세   25 non-null     object
#  6   20~24세   25 non-null     object
#  7   25~29세   25 non-null     object
#  8   30~34세   25 non-null     object
#  9   35~39세   25 non-null     object
#  10  40~44세   25 non-null     object
#  11  45~49세   25 non-null     object
#  12  50~54세   25 non-null     object
#  13  55~59세   25 non-null     object
#  14  60~64세   25 non-null     object
#  15  65~69세   25 non-null     object
#  16  70~74세   25 non-null     object
#  17  75~79세   25 non-null     object
#  18  80~84세   25 non-null     object
#  19  85~89세   25 non-null     object
# ...

# %%
for column in ['합계', '0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세',
               '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상']:
    people_2023_1[column] = pd.to_numeric(people_2023_1[column], errors='coerce')

people_2023_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     int64
#  2   0~4세     25 non-null     int64
#  3   5~9세     25 non-null     int64
#  4   10~14세   25 non-null     int64
#  5   15~19세   25 non-null     int64
#  6   20~24세   25 non-null     int64
#  7   25~29세   25 non-null     int64
#  8   30~34세   25 non-null     int64
#  9   35~39세   25 non-null     int64
#  10  40~44세   25 non-null     int64
#  11  45~49세   25 non-null     int64
#  12  50~54세   25 non-null     int64
#  13  55~59세   25 non-null     int64
#  14  60~64세   25 non-null     int64
#  15  65~69세   25 non-null     int64
#  16  70~74세   25 non-null     int64
#  17  75~79세   25 non-null     int64
#  18  80~84세   25 non-null     int64
#  19  85~89세   25 non-null     int64
#  20  90~94세   25 non-null     int64
# ...

# %%
people_2023_1['20대 미만'] = people_2023_1['0~4세'] +	people_2023_1['5~9세'] + people_2023_1['10~14세'] +	people_2023_1['15~19세']
people_2023_1['20-30대'] = people_2023_1['20~24세'] +	people_2023_1['25~29세'] + people_2023_1['30~34세'] +	people_2023_1['35~39세']
people_2023_1['40-50대'] = people_2023_1['40~44세'] +	people_2023_1['45~49세'] + people_2023_1['50~54세'] +	people_2023_1['55~59세']
people_2023_1['60-70대'] = people_2023_1['60~64세'] +	people_2023_1['65~69세'] + people_2023_1['70~74세'] +	people_2023_1['75~79세']
people_2023_1['80대 이상'] = people_2023_1['80~84세'] +	people_2023_1['85~89세'] + people_2023_1['90~94세'] +	people_2023_1['95~99세'] + people_2023_1['100세 이상']
people_age_2023_1 = people_2023_1.drop(['0~4세',	'5~9세', '10~14세',	'15~19세', '20~24세',	'25~29세', '30~34세',	'35~39세', '40~44세',	'45~49세', '50~54세',
                                '55~59세', '60~64세',	'65~69세', '70~74세',	'75~79세', '80~84세',	'85~89세', '90~94세',	'95~99세', '100세 이상'], axis = 1)
people_age_2023_1.head()
# Out:
#     지역      합계  20대 미만  20-30대  40-50대  60-70대  80대 이상
# 0  종로구  152212   17294   48801   46043   32508    7566
# 1   중구  131390   13222   43524   38931   29330    6383
# 2  용산구  232482   28337   75095   72584   46062   10404
# 3  성동구  287240   36885   91713   88386   59008   11248
# 4  광진구  350925   41738  123287  104898   69001   12001

# %%
people_age_2023_1['20대 미만 비율'] = people_age_2023_1['20대 미만'] / people_age_2023_1['합계'] * 100
people_age_2023_1['20-30대 비율'] = people_age_2023_1['20-30대'] / people_age_2023_1['합계'] * 100
people_age_2023_1['40-50대 비율'] = people_age_2023_1['40-50대'] / people_age_2023_1['합계'] * 100
people_age_2023_1['60-70대 비율'] = people_age_2023_1['60-70대'] / people_age_2023_1['합계'] * 100
people_age_2023_1['80대 이상 비율'] = people_age_2023_1['80대 이상'] / people_age_2023_1['합계'] * 100

people_agerate_2023_1 = people_age_2023_1[['지역', '합계', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']]
people_agerate_2023_1['20대 미만 비율'] = people_agerate_2023_1['20대 미만 비율'].round(2)
people_agerate_2023_1['20-30대 비율'] = people_agerate_2023_1['20-30대 비율'].round(2)
people_agerate_2023_1['40-50대 비율'] = people_agerate_2023_1['40-50대 비율'].round(2)
people_agerate_2023_1['60-70대 비율'] = people_agerate_2023_1['60-70대 비율'].round(2)
people_agerate_2023_1['80대 이상 비율'] = people_agerate_2023_1['80대 이상 비율'].round(2)
people_agerate_2023_1.head()
# Out:
# <ipython-input-32-496a4dd74050>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2023_1['20대 미만 비율'] = people_agerate_2023_1['20대 미만 비율'].round(2)
# <ipython-input-32-496a4dd74050>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2023_1['20-30대 비율'] = people_agerate_2023_1['20-30대 비율'].round(2)
# <ipython-input-32-496a4dd74050>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## 2023년 2분기

# %%
people_2023_2 = people_2023.iloc[:, list(range(3)) + list(range(25, 47))]

# %%
people_2023_2.head()
# Out:
#    동별(1)  동별(2)   항목 2023 2/4 2023 2/4.1 2023 2/4.2 2023 2/4.3 2023 2/4.4  \
# 0  동별(1)  동별(2)   항목       합계       0~4세       5~9세     10~14세     15~19세
# 1     합계     소계    계  9659322     224315     314486     362807     390695
# 2     합계     소계  한국인  9414093     219871     308730     358525     384081
# 3     합계     소계  외국인   245229       4444       5756       4282       6614
# 4    종로구     소계    계   151349       2570       3916       4838       5749
#
#   2023 2/4.5 2023 2/4.6  ... 2023 2/4.12 2023 2/4.13 2023 2/4.14 2023 2/4.15  \
# 0     20~24세     25~29세  ...      55~59세      60~64세      65~69세      70~74세
# 1     610219     845359  ...      707994      735093      598180      415728
# 2     568949     807094  ...      687323      720743      591757      413214
# 3      41270      38265  ...       20671       14350        6423        2514
# 4      12719      14670  ...       11781       11840        9219        6251
#
# ...

# %%
people_2023_2 = people_2023_2.rename(columns=people_2023_2.iloc[0]).drop(people_2023_2.index[0]).reset_index(drop=True)
people_2023_2 = people_2023_2.drop(people_2023_2.index[:3])
people_2023_2 = people_2023_2[~people_2023_2['동별(2)'].str.contains('동')]
people_2023_2 = people_2023_2[~people_2023_2['항목'].str.contains('인')]
people_2023_2
# Out:
#     동별(1) 동별(2) 항목      합계   0~4세   5~9세 10~14세 15~19세 20~24세 25~29세  ...  \
# 3     종로구    소계  계  151349   2570   3916   4838   5749  12719  14670  ...
# 57     중구    소계  계  132054   2957   3360   3150   3693   8716  12762  ...
# 105   용산구    소계  계  232069   5727   7015   7327   8014  13053  20387  ...
# 108   성동구    소계  계  286564   8278   9372   8611  10178  19331  25681  ...
# 111   광진구    소계  계  350820   6713   9610  11572  13394  27383  38875  ...
# 114  동대문구    소계  계  355667   8138  10428  10883  12662  32378  35920  ...
# 117   중랑구    소계  계  389316   9031  11096  11881  12893  20663  31838  ...
# 120   성북구    소계  계  441065  10368  14924  16936  19779  36008  36228  ...
# 123   강북구    소계  계  295773   4924   7457   9265  10640  18281  22535  ...
# 126   도봉구    소계  계  311386   5885   9039  10849  12167  17482  21561  ...
# 129   노원구    소계  계  504641  10906  16402  21783  26611  35115  34189  ...
# 132   은평구    소계  계  467295  10356  14430  16968  18935  26176  36531  ...
# ...

# %%
people_2023_2 = people_2023_2.drop(['동별(2)', '항목'], axis = 1)
columns = {'동별(1)' : '지역'}
people_2023_2 = people_2023_2.rename(columns = columns)
people_2023_2 = people_2023_2.reset_index(drop = True)
people_2023_2.head()
# Out:
#     지역      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  ...  \
# 0  종로구  151349  2570  3916   4838   5749  12719  14670  11676   9347  ...
# 1   중구  132054  2957  3360   3150   3693   8716  12762  12381  10142  ...
# 2  용산구  232069  5727  7015   7327   8014  13053  20387  22663  18973  ...
# 3  성동구  286564  8278  9372   8611  10178  19331  25681  24321  22452  ...
# 4  광진구  350820  6713  9610  11572  13394  27383  38875  32750  24466  ...
#
#   55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 0  11781  11840   9219   6251   5295   4392   2251    745    194      36
# 1   9953  10422   8566   5865   4702   3710   1816    688    169      30
# 2  16970  17054  13420   8860   7009   5765   3228   1127    247      61
# 3  21490  22018  16823  11338   8948   6837   3290   1007    221      50
# 4  25876  26206  20051  13253   9980   7318   3432   1079    261      44
#
# [5 rows x 23 columns]

# %%
for column in ['합계', '0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세',
               '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상']:
    people_2023_2[column] = pd.to_numeric(people_2023_2[column], errors='coerce')

people_2023_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     int64
#  2   0~4세     25 non-null     int64
#  3   5~9세     25 non-null     int64
#  4   10~14세   25 non-null     int64
#  5   15~19세   25 non-null     int64
#  6   20~24세   25 non-null     int64
#  7   25~29세   25 non-null     int64
#  8   30~34세   25 non-null     int64
#  9   35~39세   25 non-null     int64
#  10  40~44세   25 non-null     int64
#  11  45~49세   25 non-null     int64
#  12  50~54세   25 non-null     int64
#  13  55~59세   25 non-null     int64
#  14  60~64세   25 non-null     int64
#  15  65~69세   25 non-null     int64
#  16  70~74세   25 non-null     int64
#  17  75~79세   25 non-null     int64
#  18  80~84세   25 non-null     int64
#  19  85~89세   25 non-null     int64
#  20  90~94세   25 non-null     int64
# ...

# %%
people_2023_2['20대 미만'] = people_2023_2['0~4세'] +	people_2023_2['5~9세'] + people_2023_2['10~14세'] +	people_2023_2['15~19세']
people_2023_2['20-30대'] = people_2023_2['20~24세'] +	people_2023_2['25~29세'] + people_2023_2['30~34세'] +	people_2023_2['35~39세']
people_2023_2['40-50대'] = people_2023_2['40~44세'] +	people_2023_2['45~49세'] + people_2023_2['50~54세'] +	people_2023_2['55~59세']
people_2023_2['60-70대'] = people_2023_2['60~64세'] +	people_2023_2['65~69세'] + people_2023_2['70~74세'] +	people_2023_2['75~79세']
people_2023_2['80대 이상'] = people_2023_2['80~84세'] +	people_2023_2['85~89세'] + people_2023_2['90~94세'] +	people_2023_2['95~99세'] + people_2023_2['100세 이상']
people_age_2023_2 = people_2023_2.drop(['0~4세',	'5~9세', '10~14세',	'15~19세', '20~24세',	'25~29세', '30~34세',	'35~39세', '40~44세',	'45~49세', '50~54세',
                                '55~59세', '60~64세',	'65~69세', '70~74세',	'75~79세', '80~84세',	'85~89세', '90~94세',	'95~99세', '100세 이상'], axis = 1)
people_age_2023_2.head()
# Out:
#     지역      합계  20대 미만  20-30대  40-50대  60-70대  80대 이상
# 0  종로구  151349   17073   48412   45641   32605    7618
# 1   중구  132054   13160   44001   38925   29555    6413
# 2  용산구  232069   28083   75076   72139   46343   10428
# 3  성동구  286564   36439   91785   87808   59127   11405
# 4  광진구  350820   41289  123474  104433   69490   12134

# %%
people_age_2023_2['20대 미만 비율'] = people_age_2023_2['20대 미만'] / people_age_2023_2['합계'] * 100
people_age_2023_2['20-30대 비율'] = people_age_2023_2['20-30대'] / people_age_2023_2['합계'] * 100
people_age_2023_2['40-50대 비율'] = people_age_2023_2['40-50대'] / people_age_2023_2['합계'] * 100
people_age_2023_2['60-70대 비율'] = people_age_2023_2['60-70대'] / people_age_2023_2['합계'] * 100
people_age_2023_2['80대 이상 비율'] = people_age_2023_2['80대 이상'] / people_age_2023_2['합계'] * 100

people_agerate_2023_2 = people_age_2023_2[['지역', '합계', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']]
people_agerate_2023_2['20대 미만 비율'] = people_agerate_2023_2['20대 미만 비율'].round(2)
people_agerate_2023_2['20-30대 비율'] = people_agerate_2023_2['20-30대 비율'].round(2)
people_agerate_2023_2['40-50대 비율'] = people_agerate_2023_2['40-50대 비율'].round(2)
people_agerate_2023_2['60-70대 비율'] = people_agerate_2023_2['60-70대 비율'].round(2)
people_agerate_2023_2['80대 이상 비율'] = people_agerate_2023_2['80대 이상 비율'].round(2)
people_agerate_2023_2.head()
# Out:
# <ipython-input-39-f341fe5a7a99>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2023_2['20대 미만 비율'] = people_agerate_2023_2['20대 미만 비율'].round(2)
# <ipython-input-39-f341fe5a7a99>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2023_2['20-30대 비율'] = people_agerate_2023_2['20-30대 비율'].round(2)
# <ipython-input-39-f341fe5a7a99>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## 2023년 3분기

# %%
people_2023_3 = people_2023.iloc[:, list(range(3)) + list(range(47, len(people_2023.columns)))]

# %%
people_2023_3.head()
# Out:
#    동별(1)  동별(2)   항목 2023 3/4 2023 3/4.1 2023 3/4.2 2023 3/4.3 2023 3/4.4  \
# 0  동별(1)  동별(2)   항목       합계       0~4세       5~9세     10~14세     15~19세
# 1     합계     소계    계  9655918     220964     310468     361253     390134
# 2     합계     소계  한국인  9407540     216208     304631     356903     382203
# 3     합계     소계  외국인   248378       4756       5837       4350       7931
# 4    종로구     소계    계   151127       2556       3880       4783       5803
#
#   2023 3/4.5 2023 3/4.6  ... 2023 3/4.12 2023 3/4.13 2023 3/4.14 2023 3/4.15  \
# 0     20~24세     25~29세  ...      55~59세      60~64세      65~69세      70~74세
# 1     607352     843252  ...      714371      730420      606658      417635
# 2     563540     804892  ...      693973      716791      600380      415201
# 3      43812      38360  ...       20398       13629        6278        2434
# 4      12793      14590  ...       11837       11768        9375        6277
#
# ...

# %%
people_2023_3 = people_2023_3.rename(columns=people_2023_3.iloc[0]).drop(people_2023_3.index[0]).reset_index(drop=True)
people_2023_3 = people_2023_3.drop(people_2023_3.index[:3])
people_2023_3 = people_2023_3[~people_2023_3['동별(2)'].str.contains('동')]
people_2023_3 = people_2023_3[~people_2023_3['항목'].str.contains('인')]
people_2023_3
# Out:
#     동별(1) 동별(2) 항목      합계   0~4세   5~9세 10~14세 15~19세 20~24세 25~29세  ...  \
# 3     종로구    소계  계  151127   2556   3880   4783   5803  12793  14590  ...
# 57     중구    소계  계  131825   2934   3312   3151   3692   8674  12609  ...
# 105   용산구    소계  계  230692   5670   6920   7219   7880  12884  20227  ...
# 108   성동구    소계  계  285543   8139   9252   8522  10022  19128  25596  ...
# 111   광진구    소계  계  351959   6670   9430  11574  13525  27586  39007  ...
# 114  동대문구    소계  계  359113   8177  10554  10943  12747  32876  36201  ...
# 117   중랑구    소계  계  387940   8870  10907  11699  12738  20370  31513  ...
# 120   성북구    소계  계  440089  10106  14645  16754  19701  36385  36187  ...
# 123   강북구    소계  계  294804   4786   7273   9189  10528  18263  22575  ...
# 126   도봉구    소계  계  310133   5765   8782  10712  12035  17252  21311  ...
# 129   노원구    소계  계  504423  10861  16092  21657  26359  34930  34066  ...
# 132   은평구    소계  계  471155  10338  14500  17006  18984  26143  36705  ...
# ...

# %%
people_2023_3 = people_2023_3.drop(['동별(2)', '항목'], axis = 1)
columns = {'동별(1)' : '지역'}
people_2023_3 = people_2023_3.rename(columns = columns)
people_2023_3 = people_2023_3.reset_index(drop = True)
people_2023_3.head()
# Out:
#     지역      합계  0~4세  5~9세 10~14세 15~19세 20~24세 25~29세 30~34세 35~39세  ...  \
# 0  종로구  151127  2556  3880   4783   5803  12793  14590  11692   9274  ...
# 1   중구  131825  2934  3312   3151   3692   8674  12609  12563  10195  ...
# 2  용산구  230692  5670  6920   7219   7880  12884  20227  22656  18790  ...
# 3  성동구  285543  8139  9252   8522  10022  19128  25596  24544  22240  ...
# 4  광진구  351959  6670  9430  11574  13525  27586  39007  32977  24521  ...
#
#   55~59세 60~64세 65~69세 70~74세 75~79세 80~84세 85~89세 90~94세 95~99세 100세 이상
# 0  11837  11768   9375   6277   5300   4373   2286    760    200      39
# 1   9942  10291   8655   5875   4724   3699   1879    695    182      28
# 2  17051  16962  13513   8876   7075   5760   3272   1154    260      62
# 3  21545  21931  17122  11318   9005   6899   3361   1013    220      50
# 4  26175  26027  20419  13307  10167   7332   3516   1117    272      43
#
# [5 rows x 23 columns]

# %%
for column in ['합계', '0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세',
               '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상']:
    people_2023_3[column] = pd.to_numeric(people_2023_3[column], errors='coerce')

people_2023_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역       25 non-null     object
#  1   합계       25 non-null     int64
#  2   0~4세     25 non-null     int64
#  3   5~9세     25 non-null     int64
#  4   10~14세   25 non-null     int64
#  5   15~19세   25 non-null     int64
#  6   20~24세   25 non-null     int64
#  7   25~29세   25 non-null     int64
#  8   30~34세   25 non-null     int64
#  9   35~39세   25 non-null     int64
#  10  40~44세   25 non-null     int64
#  11  45~49세   25 non-null     int64
#  12  50~54세   25 non-null     int64
#  13  55~59세   25 non-null     int64
#  14  60~64세   25 non-null     int64
#  15  65~69세   25 non-null     int64
#  16  70~74세   25 non-null     int64
#  17  75~79세   25 non-null     int64
#  18  80~84세   25 non-null     int64
#  19  85~89세   25 non-null     int64
#  20  90~94세   25 non-null     int64
# ...

# %%
people_2023_3['20대 미만'] = people_2023_3['0~4세'] +	people_2023_3['5~9세'] + people_2023_3['10~14세'] +	people_2023_3['15~19세']
people_2023_3['20-30대'] = people_2023_3['20~24세'] +	people_2023_3['25~29세'] + people_2023_3['30~34세'] +	people_2023_3['35~39세']
people_2023_3['40-50대'] = people_2023_3['40~44세'] +	people_2023_3['45~49세'] + people_2023_3['50~54세'] +	people_2023_3['55~59세']
people_2023_3['60-70대'] = people_2023_3['60~64세'] +	people_2023_3['65~69세'] + people_2023_3['70~74세'] +	people_2023_3['75~79세']
people_2023_3['80대 이상'] = people_2023_3['80~84세'] +	people_2023_3['85~89세'] + people_2023_3['90~94세'] +	people_2023_3['95~99세'] + people_2023_3['100세 이상']
people_age_2023_3 = people_2023_3.drop(['0~4세',	'5~9세', '10~14세',	'15~19세', '20~24세',	'25~29세', '30~34세',	'35~39세', '40~44세',	'45~49세', '50~54세',
                                '55~59세', '60~64세',	'65~69세', '70~74세',	'75~79세', '80~84세',	'85~89세', '90~94세',	'95~99세', '100세 이상'], axis = 1)
people_age_2023_3.head()
# Out:
#     지역      합계  20대 미만  20-30대  40-50대  60-70대  80대 이상
# 0  종로구  151127   17022   48349   45378   32720    7658
# 1   중구  131825   13089   44041   38667   29545    6483
# 2  용산구  230692   27689   74557   71512   46426   10508
# 3  성동구  285543   35935   91508   87181   59376   11543
# 4  광진구  351959   41199  124091  104469   69920   12280

# %%
people_age_2023_3['20대 미만 비율'] = people_age_2023_3['20대 미만'] / people_age_2023_3['합계'] * 100
people_age_2023_3['20-30대 비율'] = people_age_2023_3['20-30대'] / people_age_2023_3['합계'] * 100
people_age_2023_3['40-50대 비율'] = people_age_2023_3['40-50대'] / people_age_2023_3['합계'] * 100
people_age_2023_3['60-70대 비율'] = people_age_2023_3['60-70대'] / people_age_2023_3['합계'] * 100
people_age_2023_3['80대 이상 비율'] = people_age_2023_3['80대 이상'] / people_age_2023_3['합계'] * 100

people_agerate_2023_3 = people_age_2023_3[['지역', '합계', '20대 미만 비율', '20-30대 비율', '40-50대 비율', '60-70대 비율', '80대 이상 비율']]
people_agerate_2023_3['20대 미만 비율'] = people_agerate_2023_3['20대 미만 비율'].round(2)
people_agerate_2023_3['20-30대 비율'] = people_agerate_2023_3['20-30대 비율'].round(2)
people_agerate_2023_3['40-50대 비율'] = people_agerate_2023_3['40-50대 비율'].round(2)
people_agerate_2023_3['60-70대 비율'] = people_agerate_2023_3['60-70대 비율'].round(2)
people_agerate_2023_3['80대 이상 비율'] = people_agerate_2023_3['80대 이상 비율'].round(2)
people_agerate_2023_3.head()
# Out:
# <ipython-input-46-1a24326f4bab>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2023_3['20대 미만 비율'] = people_agerate_2023_3['20대 미만 비율'].round(2)
# <ipython-input-46-1a24326f4bab>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_agerate_2023_3['20-30대 비율'] = people_agerate_2023_3['20-30대 비율'].round(2)
# <ipython-input-46-1a24326f4bab>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # 저장

# %%
from google.colab import files
people_agerate_2021.to_csv('서울시 2021년 연령별 거주비율.csv', index=False)
people_agerate_2022.to_csv('서울시 2022년 연령별 거주비율.csv', index=False)
people_agerate_2023_1.to_csv('서울시 2023년 1분기 연령별 거주비율.csv', index=False)
people_agerate_2023_2.to_csv('서울시 2023년 2분기 연령별 거주비율.csv', index=False)
people_agerate_2023_3.to_csv('서울시 2023년 3분기 연령별 거주비율.csv', index=False)

files.download('서울시 2021년 연령별 거주비율.csv')
files.download('서울시 2022년 연령별 거주비율.csv')
files.download('서울시 2023년 1분기 연령별 거주비율.csv')
files.download('서울시 2023년 2분기 연령별 거주비율.csv')
files.download('서울시 2023년 3분기 연령별 거주비율.csv')
