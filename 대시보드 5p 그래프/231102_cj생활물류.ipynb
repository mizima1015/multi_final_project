# %% [markdown]
# # 라이브러리 설치

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 한글 시각화 준비

# %%
# !pip install koreanize-matplotlib

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.figure(figsize=(4,3))
plt.plot([-1, 0, 1, 2])
plt.xlabel('간단한 그래프')
plt.show()

# %% [markdown]
# # 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data_frames = []

path = '/content/drive/MyDrive/Colab Notebooks/프로젝트/파이널프로젝트/seoul_tr_data/REC_SEND/'

for year in range(2021, 2024):
    for month in range(1, 13):
        filename = f"{str(year)[2:]}_{str(month).zfill(2)}.csv"
        file_path = path + filename

        if os.path.exists(file_path):
            df1 = pd.read_csv(file_path, encoding='euc-kr')
            data_frames.append(df1)
        else:
          print("파일이 존재하지 않습니다.")
# Out:
# 파일이 존재하지 않습니다.
# 파일이 존재하지 않습니다.
# 파일이 존재하지 않습니다.
# 파일이 존재하지 않습니다.

# %%
df1 = pd.concat(data_frames, ignore_index=True)
df1.tail()
# Out:
#           DL_YMD SEND_CTPV_NM  SEND_CTPV_CD SEND_CTGG_NM  SEND_CTGG_CD  \
# 559069  20230831        서울특별시          11.0          양천구       11470.0
# 559070  20230831        서울특별시          11.0          양천구       11470.0
# 559071  20230831        서울특별시          11.0          양천구       11470.0
# 559072  20230831        서울특별시          11.0          양천구       11470.0
# 559073  20230831        서울특별시          11.0          양천구       11470.0
#
#        REC_CTPV_NM  REC_CTPV_CD REC_CTGG_NM  REC_CTGG_CD  E_C_01  E_C_02  \
# 559069       서울특별시         11.0         관악구      11620.0     0.0    21.0
# 559070       서울특별시         11.0         서초구      11650.0     0.0    16.0
# 559071       서울특별시         11.0         강남구      11680.0     3.0    35.0
# 559072       서울특별시         11.0         송파구      11710.0     5.0    28.0
# 559073       서울특별시         11.0         강동구      11740.0     4.0    10.0
#
#         E_C_03  E_C_04  E_C_05  E_C_06  E_C_07  E_C_08  E_C_09  E_C_10  E_C_11
# ...

# %%
df1['DL_YMD'].value_counts()
# Out:
# 20210115    625
# 20220907    625
# 20220811    625
# 20220816    625
# 20220820    625
#            ...
# 20220911     29
# 20220201     26
# 20230122     11
# 20210212      4
# 20220910      1
# Name: DL_YMD, Length: 973, dtype: int64

# %%
df1['DL_DIRECTION'] = '서울_서울'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559074 entries, 0 to 559073
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DL_YMD        559074 non-null  int64
#  1   SEND_CTPV_NM  559074 non-null  object
#  2   SEND_CTPV_CD  559074 non-null  float64
#  3   SEND_CTGG_NM  559074 non-null  object
#  4   SEND_CTGG_CD  559074 non-null  float64
#  5   REC_CTPV_NM   559074 non-null  object
#  6   REC_CTPV_CD   559074 non-null  float64
#  7   REC_CTGG_NM   559074 non-null  object
#  8   REC_CTGG_CD   559074 non-null  float64
#  9   E_C_01        559074 non-null  float64
#  10  E_C_02        559074 non-null  float64
#  11  E_C_03        559074 non-null  float64
#  12  E_C_04        559074 non-null  float64
#  13  E_C_05        559074 non-null  float64
#  14  E_C_06        559074 non-null  float64
#  15  E_C_07        559074 non-null  float64
#  16  E_C_08        559074 non-null  float64
# ...

# %%
df1.to_csv('rec_send_total.csv')

# %%
data_frames2 = []

path2 = '/content/drive/MyDrive/Colab Notebooks/프로젝트/파이널프로젝트/seoul_tr_data/REC/'

for year in range(2021, 2024):
    for month in range(1, 13):
        filename2 = f"{str(year)[2:]}_{str(month).zfill(2)}.csv"
        file_path2 = path2 + filename2

        if os.path.exists(file_path2):
            df2 = pd.read_csv(file_path2, encoding='euc-kr')
            data_frames2.append(df2)
        else:
          print("파일이 존재하지 않습니다.")
# Out:
# 파일이 존재하지 않습니다.
# 파일이 존재하지 않습니다.
# 파일이 존재하지 않습니다.
# 파일이 존재하지 않습니다.

# %%
df2 = pd.concat(data_frames2, ignore_index=True)
df2.tail()
# Out:
#           DL_YMD SEND_CTPV_NM  SEND_CTPV_CD REC_CTPV_NM  REC_CTPV_CD  \
# 404350  20230827        인천광역시          28.0       서울특별시         11.0
# 404351  20230827        인천광역시          28.0       서울특별시         11.0
# 404352  20230827        인천광역시          28.0       서울특별시         11.0
# 404353  20230827        인천광역시          28.0       서울특별시         11.0
# 404354  20230827        인천광역시          28.0       서울특별시         11.0
#
#        REC_CTGG_NM  REC_CTGG_CD  E_C_01  E_C_02  E_C_03  E_C_04  E_C_05  \
# 404350         관악구      11620.0    17.0    73.0    18.0    70.0   116.0
# 404351         서초구      11650.0    12.0    86.0    30.0    66.0   101.0
# 404352         강남구      11680.0    26.0   152.0    32.0   107.0   141.0
# 404353         송파구      11710.0    27.0    91.0    37.0   105.0   149.0
# 404354         강동구      11740.0    16.0    65.0    18.0    82.0   106.0
#
#         E_C_06  E_C_07  E_C_08  E_C_09  E_C_10  E_C_11
# 404350    37.0   117.0    10.0    96.0   170.0    64.0
# ...

# %%
df2['DL_DIRECTION'] = '전국_서울'

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404355 entries, 0 to 404354
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DL_YMD        404355 non-null  int64
#  1   SEND_CTPV_NM  404355 non-null  object
#  2   SEND_CTPV_CD  404355 non-null  float64
#  3   REC_CTPV_NM   404355 non-null  object
#  4   REC_CTPV_CD   404355 non-null  float64
#  5   REC_CTGG_NM   404355 non-null  object
#  6   REC_CTGG_CD   404355 non-null  float64
#  7   E_C_01        404355 non-null  float64
#  8   E_C_02        404355 non-null  float64
#  9   E_C_03        404355 non-null  float64
#  10  E_C_04        404355 non-null  float64
#  11  E_C_05        404355 non-null  float64
#  12  E_C_06        404355 non-null  float64
#  13  E_C_07        404355 non-null  float64
#  14  E_C_08        404355 non-null  float64
#  15  E_C_09        404355 non-null  float64
#  16  E_C_10        404355 non-null  float64
# ...

# %%
df2.to_csv('rec.csv')

# %%
df2.columns
# Out:
# Index(['DL_YMD', 'SEND_CTPV_NM', 'SEND_CTPV_CD', 'REC_CTPV_NM', 'REC_CTPV_CD',
#        'REC_CTGG_NM', 'REC_CTGG_CD', 'E_C_01', 'E_C_02', 'E_C_03', 'E_C_04',
#        'E_C_05', 'E_C_06', 'E_C_07', 'E_C_08', 'E_C_09', 'E_C_10', 'E_C_11',
#        'DL_DIRECTION'],
#       dtype='object')

# %% [markdown]
# # 데이터 합치기

# %%
key = ['DL_YMD', 'SEND_CTPV_NM', 'SEND_CTPV_CD', 'REC_CTPV_NM', 'REC_CTPV_CD',
       'REC_CTGG_NM', 'REC_CTGG_CD', 'E_C_01', 'E_C_02', 'E_C_03', 'E_C_04',
       'E_C_05', 'E_C_06', 'E_C_07', 'E_C_08', 'E_C_09', 'E_C_10', 'E_C_11',
       'DL_DIRECTION']
df = pd.merge(df1, df2, on=key, how='outer')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 963429 entries, 0 to 963428
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DL_YMD        963429 non-null  int64
#  1   SEND_CTPV_NM  963429 non-null  object
#  2   SEND_CTPV_CD  963429 non-null  float64
#  3   SEND_CTGG_NM  559074 non-null  object
#  4   SEND_CTGG_CD  559074 non-null  float64
#  5   REC_CTPV_NM   963429 non-null  object
#  6   REC_CTPV_CD   963429 non-null  float64
#  7   REC_CTGG_NM   963429 non-null  object
#  8   REC_CTGG_CD   963429 non-null  float64
#  9   E_C_01        963429 non-null  float64
#  10  E_C_02        963429 non-null  float64
#  11  E_C_03        963429 non-null  float64
#  12  E_C_04        963429 non-null  float64
#  13  E_C_05        963429 non-null  float64
#  14  E_C_06        963429 non-null  float64
#  15  E_C_07        963429 non-null  float64
#  16  E_C_08        963429 non-null  float64
# ...

# %% [markdown]
# # 결측치 처리

# %%
df[df['SEND_CTGG_NM'].isna()]
# Out:
#           DL_YMD SEND_CTPV_NM  SEND_CTPV_CD SEND_CTGG_NM  SEND_CTGG_CD  \
# 559074  20210103         충청북도          43.0          NaN           NaN
# 559075  20210103         충청북도          43.0          NaN           NaN
# 559076  20210103         충청북도          43.0          NaN           NaN
# 559077  20210103         충청북도          43.0          NaN           NaN
# 559078  20210103         충청북도          43.0          NaN           NaN
# ...          ...          ...           ...          ...           ...
# 963424  20230827        인천광역시          28.0          NaN           NaN
# 963425  20230827        인천광역시          28.0          NaN           NaN
# 963426  20230827        인천광역시          28.0          NaN           NaN
# 963427  20230827        인천광역시          28.0          NaN           NaN
# 963428  20230827        인천광역시          28.0          NaN           NaN
#
#        REC_CTPV_NM  REC_CTPV_CD REC_CTGG_NM  REC_CTGG_CD  E_C_01  ...  E_C_03  \
# ...

# %%
df['SEND_CTGG_NM'].fillna(0, inplace=True)
df['SEND_CTGG_CD'].fillna(0, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 963429 entries, 0 to 963428
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DL_YMD        963429 non-null  int64
#  1   SEND_CTPV_NM  963429 non-null  object
#  2   SEND_CTPV_CD  963429 non-null  float64
#  3   SEND_CTGG_NM  963429 non-null  object
#  4   SEND_CTGG_CD  963429 non-null  float64
#  5   REC_CTPV_NM   963429 non-null  object
#  6   REC_CTPV_CD   963429 non-null  float64
#  7   REC_CTGG_NM   963429 non-null  object
#  8   REC_CTGG_CD   963429 non-null  float64
#  9   E_C_01        963429 non-null  float64
#  10  E_C_02        963429 non-null  float64
#  11  E_C_03        963429 non-null  float64
#  12  E_C_04        963429 non-null  float64
#  13  E_C_05        963429 non-null  float64
#  14  E_C_06        963429 non-null  float64
#  15  E_C_07        963429 non-null  float64
#  16  E_C_08        963429 non-null  float64
# ...

# %%
df['DL_YMD'] = pd.to_datetime(df['DL_YMD'], format='%Y%m%d')

df.insert(df.columns.get_loc('DL_YMD') + 1, 'YEAR', df['DL_YMD'].dt.year)
df.insert(df.columns.get_loc('YEAR') + 1, 'MONTH', df['DL_YMD'].dt.month)
df.insert(df.columns.get_loc('MONTH') + 1, 'DAY', df['DL_YMD'].dt.day)

# %%
df.rename(columns=
          {'DL_YMD': '배송년월일',
           'YEAR' : '년',
           'MONTH' : '월',
           'DAY' : '일',
          'SEND_CTPV_NM': '보내는_시명',
          'SEND_CTPV_CD': '보내는_시코드',
          'SEND_CTGG_NM': '보내는_구명',
          'SEND_CTGG_CD': '보내는_구코드',
          'REC_CTPV_NM': '받는_시명',
          'REC_CTPV_CD': '받는_시코드',
          'REC_CTGG_NM': '받는_구명',
          'REC_CTGG_CD': '받는_구코드',
          'E_C_01': '가구/인테리어',
          'E_C_02': '기타',
          'E_C_03': '도서/음반',
          'E_C_04': '디지털/가전',
          'E_C_05': '생활/건강',
          'E_C_06': '스포츠/레저',
          'E_C_07': '식품',
          'E_C_08': '출산/육아',
          'E_C_09': '패션의류',
          'E_C_10': '패션잡화',
          'E_C_11': '화장품/미용',
           'DL_DIRECTION' : '배송방향'}, inplace=True)
df.head(2)
# Out:
#        배송년월일     년  월   일 보내는_시명  보내는_시코드 보내는_구명  보내는_구코드  받는_시명  받는_시코드  ...  \
# 0 2021-01-15  2021  1  15  서울특별시     11.0    양천구  11470.0  서울특별시    11.0  ...
# 1 2021-01-15  2021  1  15  서울특별시     11.0    양천구  11470.0  서울특별시    11.0  ...
#
#   도서/음반  디지털/가전  생활/건강  스포츠/레저    식품  출산/육아  패션의류  패션잡화  화장품/미용   배송방향
# 0   0.0     8.0   37.0     3.0  11.0    0.0  22.0  12.0     5.0  서울_서울
# 1   9.0    10.0   29.0     4.0  19.0    0.0  38.0   8.0    10.0  서울_서울
#
# [2 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['배송년월일', '년', '월', '일', '보내는_시명', '보내는_시코드', '보내는_구명', '보내는_구코드',
#        '받는_시명', '받는_시코드', '받는_구명', '받는_구코드', '가구/인테리어', '기타', '도서/음반',
#        '디지털/가전', '생활/건강', '스포츠/레저', '식품', '출산/육아', '패션의류', '패션잡화', '화장품/미용',
#        '배송방향'],
#       dtype='object')

# %%
df['보내는_시명'].value_counts()
# Out:
# 서울특별시      583332
# 경기도         24271
# 인천광역시       24188
# 충청북도        23950
# 제주특별자치도     23927
# 대전광역시       23881
# 경상북도        23863
# 전라북도        23859
# 충청남도        23790
# 대구광역시       23779
# 경상남도        23750
# 부산광역시       23654
# 전라남도        23609
# 세종특별자치시     23496
# 광주광역시       23358
# 울산광역시       23166
# 강원도         21301
# 강원특별자치도      2255
# Name: 보내는_시명, dtype: int64

# %%
df['보내는_구명'].value_counts()
# Out:
# 0       404355
# 강서구      23969
# 성북구      23858
# 금천구      23542
# 구로구      23325
# 중구       23291
# 강남구      23222
# 서초구      23179
# 성동구      23134
# 송파구      23010
# 영등포구     22909
# 마포구      22751
# 용산구      22610
# 노원구      22322
# 광진구      22321
# 동대문구     22187
# 중랑구      22127
# 강동구      21872
# 종로구      21780
# 은평구      21445
# 도봉구      21288
# 서대문구     21223
# 동작구      21066
# 양천구      21047
# 관악구      20893
# 강북구      20703
# Name: 보내는_구명, dtype: int64

# %%
df.head(2)
# Out:
#        배송년월일     년  월   일 보내는_시명  보내는_시코드 보내는_구명  보내는_구코드  받는_시명  받는_시코드  ...  \
# 0 2021-01-15  2021  1  15  서울특별시     11.0    양천구  11470.0  서울특별시    11.0  ...
# 1 2021-01-15  2021  1  15  서울특별시     11.0    양천구  11470.0  서울특별시    11.0  ...
#
#   도서/음반  디지털/가전  생활/건강  스포츠/레저    식품  출산/육아  패션의류  패션잡화  화장품/미용   배송방향
# 0   0.0     8.0   37.0     3.0  11.0    0.0  22.0  12.0     5.0  서울_서울
# 1   9.0    10.0   29.0     4.0  19.0    0.0  38.0   8.0    10.0  서울_서울
#
# [2 rows x 24 columns]

# %%
df['년'].value_counts()
# Out:
# 2021    362809
# 2022    361464
# 2023    239156
# Name: 년, dtype: int64

# %%
df.columns
# Out:
# Index(['배송년월일', '년', '월', '일', '보내는_시명', '보내는_시코드', '보내는_구명', '보내는_구코드',
#        '받는_시명', '받는_시코드', '받는_구명', '받는_구코드', '가구/인테리어', '기타', '도서/음반',
#        '디지털/가전', '생활/건강', '스포츠/레저', '식품', '출산/육아', '패션의류', '패션잡화', '화장품/미용',
#        '배송방향'],
#       dtype='object')

# %%
product = ['가구/인테리어', '기타', '도서/음반', '디지털/가전', '생활/건강', '스포츠/레저', '식품', '출산/육아', '패션의류', '패션잡화', '화장품/미용']
temp1 = df.groupby('년')[product].mean()
print(temp1)
# Out:
#         가구/인테리어          기타      도서/음반     디지털/가전       생활/건강     스포츠/레저  \
# 년
# 2021  33.452632  144.666425  60.542415  81.041730  185.703130  22.462985
# 2022  25.911230  200.809480  50.655011  62.682452  150.410594  21.248321
# 2023  24.586065  105.404673  55.235616  65.010157  143.244029  21.581599
#
#               식품      출산/육아        패션의류       패션잡화     화장품/미용
# 년
# 2021  268.588773  25.970318  202.864455  77.161460  95.282942
# 2022  223.575587  22.139737  196.110052  77.166921  88.700001
# 2023  224.144905  21.910176  197.132930  81.876307  92.043315

# %%
plt.figure(figsize=(12, 6))

for product in temp1.columns:
  plt.plot(temp1.index, temp1[product], marker='o', label=product)

plt.title('연도별 품목별 평균 택배 물량')
plt.xlabel('연도')
plt.ylabel('평균 택배 물량')

plt.legend()
plt.show()

# %% [markdown]
# - TOP3 : 식품, 패션의류, 생활건강 품목 순으로 연평균 택배 물량이 많음.
# - LOW3 : 스포츠/레저, 출산/육아, 화장품/미용 순으로 평균 택배 물량 적음.
# - 2022년 기타 품목 상승
# - 2022년 식품 품목 하락

# %%
product = ['가구/인테리어', '기타', '도서/음반', '디지털/가전', '생활/건강', '스포츠/레저', '식품', '출산/육아', '패션의류', '패션잡화', '화장품/미용']
temp2 = df.groupby('월')[product].mean()
print(temp2)
# Out:
#       가구/인테리어          기타      도서/음반     디지털/가전       생활/건강     스포츠/레저  \
# 월
# 1   20.421725  437.955202  45.826123  54.479325  119.373379  12.763541
# 2   30.465581  126.141305  67.487297  80.293535  174.554076  18.613487
# 3   30.759621  131.315752  67.260717  75.006376  174.451476  20.469835
# 4   27.650589  124.373820  53.449800  67.363158  159.012293  21.382048
# 5   27.749937  127.707283  51.793736  69.141974  159.618185  23.605550
# 6   28.447710  129.367814  51.819718  70.365137  161.771209  24.094340
# 7   28.043018  125.223397  51.270071  69.117680  156.531494  23.611169
# 8   27.516972  120.722927  54.244635  70.757002  166.941583  23.828534
# 9   30.445014  130.738480  61.544197  72.942567  173.465361  23.130320
# 10  29.723790  120.532185  52.036014  70.304087  160.024939  22.595861
# 11  31.144956  128.909562  52.596702  75.053193  172.486489  24.117885
# 12  31.916560  133.324665  58.809624  70.845279  177.190519  25.528456
#
# ...

# %%
plt.figure(figsize=(12, 6))

for product in temp2.columns:
  plt.plot(temp2.index, temp2[product], marker='o', label=product)

plt.title('월별 품목별 평균 택배 물량')
plt.xlabel('월')
plt.ylabel('평균 택배 물량')

plt.legend()
plt.show()

# %% [markdown]
# - 식품, 패션의류, 생활/건강 순으로 월평균 택배 물량 많음.
# - 식품 품목 : 2월 상승, 3~7월까지는 소폭 하락세 유지, 9월 최고점,
# - 패션의류 : 3~6월까지 소폭 상승, 8월 최하점, 9~11월 소폭 상승세 유지

# %% [markdown]
# # 음반 (1)
# - 방탄소년단 <Proof> 2022년 6월 10일 발매
#   - 발매 첫날 더블 밀리언셀러 등극 ([참고기사](https://www.bbc.com/korean/news-61757236))
#   - 발매 전 일주일, 발매 후 일주일의 도서/음반 물량 비교

# %%
# 날짜 범위에 따라 데이터 필터링
before_release_data = df[(df['배송년월일'] >= '2022-06-02') & (df['배송년월일'] <= '2022-06-09')]
after_release_data = df[(df['배송년월일'] >= '2022-06-10') & (df['배송년월일'] <= '2022-06-17')]

# 도서/음반 물량 합산
before_quantity = before_release_data['도서/음반'].sum()
after_quantity = after_release_data['도서/음반'].sum()

print(before_quantity, after_quantity)

# 막대 그래프로 비교
plt.figure(figsize=(8, 6))
plt.bar(['BTS 발매 전 일주일', 'BTS 발매 후 일주일'], [before_quantity, after_quantity], color=['blue', 'green'])
plt.title('BTS 발매 전/후 도서/음반 물량 비교')
plt.xlabel('기간')
plt.ylabel('도서/음반 물량')
plt.show()
# Out:
# 385536.0 464295.0

# %% [markdown]
# # 음반 (2)
# - 스트레이키즈 <5-STARS> 2023년 6월 2일 발매
#   - 초동 판매량 케이팝 역대 1위 ([참고기사](https://star.ytn.co.kr/_sn/0117_202306091014553245))
#   - 발매 전 1주, 발매 후 1주의 도서/음반 물량 비교

# %%
# 날짜 범위에 따라 데이터 필터링
before_release_data = df[(df['배송년월일'] >= '2023-05-25') & (df['배송년월일'] <= '2023-06-01')]
after_release_data = df[(df['배송년월일'] >= '2023-06-02') & (df['배송년월일'] <= '2023-06-09')]

# 도서/음반 물량 합산
before_quantity = before_release_data['도서/음반'].sum()
after_quantity = after_release_data['도서/음반'].sum()

# 막대 그래프로 비교
plt.figure(figsize=(8, 6))
plt.bar(['스키즈 발매 전 일주일', '스키즈 발매 후 일주일'], [before_quantity, after_quantity], color=['blue', 'green'])
plt.title('스키즈 발매 전/후 도서/음반 물량 비교')
plt.xlabel('기간')
plt.ylabel('도서/음반 물량')
plt.show()

# %% [markdown]
# # 디지털
# - 아이폰 13 사전 예약일 : 2021년 10월 1일 / 출시일 : 2021년 10월 8일
# - [참고 기사](https://hypebeast.kr/2021/11/apple-iphone-13-sold-much-more-than-previous-model)
# - 사전예약 시작 전 주, 사전예약 시작 후 1주 (출시 1주 후) 디지털/가전 물량 비교

# %%
# 날짜 범위에 따라 데이터 필터링
before_release_data = df[(df['배송년월일'] >= '2021-09-23') & (df['배송년월일'] <= '2021-10-07')] # 추석일정이 껴 있어서 밀린 물량이 있을 것.
after_release_data = df[(df['배송년월일'] >= '2021-10-08') & (df['배송년월일'] <= '2021-10-22')]

# 디지털/가전 물량 합산
before_quantity = before_release_data['디지털/가전'].sum()
after_quantity = after_release_data['디지털/가전'].sum()

# 막대 그래프로 비교
plt.figure(figsize=(8, 6))
plt.bar(['아이폰 13 발매 전 이주일', '아이폰 13 발매 후 이주일'], [before_quantity, after_quantity], color=['blue', 'green'])
plt.title('아이폰 13 발매 전/후 디지털/가전 물량 비교')
plt.xlabel('기간')
plt.ylabel('디지털/가전 물량')
plt.show()

# %% [markdown]
# 왜 아이폰 발매 전 2주 (2021-09-23 ~ 2021-10-07)이 더 높은 수치로 나온걸까?
# - 가설 1: 2021년 9월 20일 ~ 22일 동안 추석 연휴라 23일에 물량이 계속 몰렸을 것.
#
# ### 추석 일정이 겹치지 않는 아이폰 14 출시일로 확인해보자
# - 아이폰 14 국내 출시일 : 2022년 10월 7일
# - 추석 : 2022년 9월 9일 ~ 11일

# %%
# 날짜 범위에 따라 데이터 필터링
before_release_data = df[(df['배송년월일'] >= '2022-09-22') & (df['배송년월일'] <= '2022-10-06')]
after_release_data = df[(df['배송년월일'] >= '2022-10-07') & (df['배송년월일'] <= '2022-10-21')]

# 디지털/가전 물량 합산
before_quantity = before_release_data['디지털/가전'].sum()
after_quantity = after_release_data['디지털/가전'].sum()

# 막대 그래프로 비교
plt.figure(figsize=(8, 6))
plt.bar(['아이폰 14 발매 전 일주일', '아이폰 14 발매 후 일주일'], [before_quantity, after_quantity], color=['blue', 'green'])
plt.title('아이폰 14 발매 전/후 디지털/가전 물량 비교')
plt.xlabel('기간')
plt.ylabel('디지털/가전 물량')
plt.show()

# %% [markdown]
# 추석 일정이 겹치지 않은 아이폰 14는 출시일 이후 2주간의 물량이 2주전에 비해 상승.
# - 택배 물량에 '추석' 같은 명절이라는 변수는 크게 작용한다는 것을 확인.
